# %% [markdown]
# # Python and PostgreSQL project part IV:
# # Using SQLAlchemy to implement SELECT queries on imported CSV data.
#
# # Overview:
# ## This notebook will iimplement various SELECT queries, such as for finding the average IGN scores for each year in the database, the average IGN scores for each game genre, etc.

# %% [markdown]
# # What is the average IGN score for the entire database/dataset?
#
# ## I.e., do a SELECT query to show the sample average of the dataset. The SQL code/syntax would be: <<< SELECT avg(score) FROM ign_ratings;

# %%
#import SQLAlchemy library 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, String, MetaData, Float, Integer, ForeignKey, Boolean

from sqlalchemy import event, select, func

#specify the table so query can be done on it
ign_ratings = Table('ign_ratings', meta,
                      Column('ID', Integer, primary_key=True),
                      Column('score_phrase', String),
                      Column('title', String),
                      Column('url', String),
                      Column('platform', String),
                      Column('score', Float),
                      Column('genre', String),
                      Column('release_year', Integer),
                      Column('release_month', Integer),
                      Column('release_day', Integer),
                      Column('editors_choice_y', Integer),
                   )

#re-specify the password, host, and other info needed to access the database
db_string = "postgres://postgres:*******@localhost:5433/goods"
db_co = create_engine(db_string)

meta = MetaData(db_co)  

with db_co.connect() as conn: 
    # do SELECT statement, and print out its output
    select_statement = select([func.avg(ign_ratings.c.score)])
    result_set = conn.execute(select_statement)
    for r in result_set:
        print(r)
# Out:
# (6.95037585910651,)

# %% [markdown]
# # Analysis of query:
# ### The sample IGN score average is 6.95. The scale is out of a 10, so this score isn't particularly high or low. Also, a score of 7 for IGN (as with many other critic review sites/organizations) is considered fair or mediocre, so a sample average of this seems fairly sensible.

# %% [markdown]
# # What are the average IGN scores for each release year in the dataset/database?
#
# # I.e., do a SELECT query to find the average IGN scores/ratings for each release year (1996-2016), and order consectively by release year:

# %%
#import SQLAlchemy library 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, String, MetaData, Float, Integer, ForeignKey, Boolean

from sqlalchemy import event, select, func

#specify the table so query can be done on it
ign_ratings = Table('ign_ratings', meta,
                      Column('ID', Integer, primary_key=True),
                      Column('score_phrase', String),
                      Column('title', String),
                      Column('url', String),
                      Column('platform', String),
                      Column('score', Float),
                      Column('genre', String),
                      Column('release_year', Integer),
                      Column('release_month', Integer),
                      Column('release_day', Integer),
                      Column('editors_choice', Integer),
                   )

#re-specify the password, host, and other info needed to access the database
db_string = "postgres://postgres:*******@localhost:5433/goods"
db_co = create_engine(db_string)

meta = MetaData(db_co)  

with db_co.connect() as conn: 
    # do SELECT statement, and print out its output
    select_statement = select([ign_ratings.c.release_year, func.avg(ign_ratings.c.score)]).group_by(ign_ratings.c.release_year).order_by(ign_ratings.c.release_year)
    result_set = conn.execute(select_statement)
    for r in result_set:
        print(r)
# Out:
# (1996, 6.16174496644295)
# (1997, 6.56634146341464)
# (1998, 6.9306784660767)
# (1999, 6.98348387096775)
# (2000, 6.69358851674641)
# (2001, 7.12049418604651)
# (2002, 6.97852564102564)
# (2003, 7.19824561403509)
# (2004, 7.17071213640923)
# (2005, 7.22242647058822)
# (2006, 6.7328642384106)
# (2007, 6.63254658385092)
# (2008, 6.4481462140992)
# (2009, 6.84036751630112)
# (2010, 6.93286867204695)
# (2011, 7.05032618825722)
# (2012, 7.4183266932271)
# (2013, 7.46048850574714)
# (2014, 7.46759776536314)
# (2015, 7.65945205479453)
# (2016, 7.57345132743363)

# %% [markdown]
# # Analysis of SELECT query results:
#
# ## Average video game ratings via IGN have fluctuated a bit over the 20-year period of 1996-2016. However, the most recent 5-year period of 2012-2016 (inclusive) has averaged higher than any other 5-year period within the database (the 2nd-highest 5-year inclusive period is 2001-2005).
#
# ## Each of the years for 2012-2016 had scores exceeding 7.4, well above the overall sample average; the best overall year in terms of average IGN scores was in 2015, with 2016 not far behind it.
#
# ## By contrast, average IGN scores were lowest during the 5-year (inclusive) period of 1996-2000. Not once did average IGN scores exceed 7, and 1996 is the lowest-rated year by a moderate margin.

# %% [markdown]
# # What are the average IGN scores for each genre in the database? How many games are there for each genre in the database?
#
# # For the next SELECT query, find the average IGN scores/ratings for each genre (i.e., use a groupby on the average of IGN scores), and perform 2 additional operations:
#
# ## a.) order the results by genre in alphabetical order; and b.) count the number of games from each genre (to get a better sense of context).

# %% [markdown]
# # This query is equivalent to the following PostgreSQL query/code:
#
# ## <<<SELECT genre,  AVG(score), COUNT(genre) FROM ign_data GROUP BY genre ORDER BY genre ;
#
# ### This will show the average IGN score/rating for each genre, and count the number of games for each genre.

# %%
#import SQLAlchemy library 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, String, MetaData, Float, Integer, ForeignKey, Boolean

from sqlalchemy import event, select, func

#specify the table so query can be done on it
ign_ratings = Table('ign_ratings', meta,
                      Column('ID', Integer, primary_key=True),
                      Column('score_phrase', String),
                      Column('title', String),
                      Column('url', String),
                      Column('platform', String),
                      Column('score', Float),
                      Column('genre', String),
                      Column('release_year', Integer),
                      Column('release_month', Integer),
                      Column('release_day', Integer),
                      Column('editors_choice', Integer),
                   )

#re-specify the password, host, and other info needed to access the database
db_string = "postgres://postgres:*******@localhost:5433/goods"
db_co = create_engine(db_string)

meta = MetaData(db_co)  

with db_co.connect() as conn: 
    # do SELECT statement, and print out its output
    select_statement = select([ign_ratings.c.genre, func.avg(ign_ratings.c.score), func.count(ign_ratings.c.genre)]).group_by(ign_ratings.c.genre).order_by(ign_ratings.c.genre)
    result_set = conn.execute(select_statement)
    for r in result_set:
        print(r)
# Out:
# ('Action', 6.62667895707138, 3797)
# ('Action, Adventure', 7.3718954248366, 765)
# ('Action, Compilation', 7.02921348314607, 89)
# ('Action, Editor', 7.5, 1)
# ('Action, Platformer', 6.06666666666667, 3)
# ('Action, Puzzle', 6.0, 1)
# ('Action, RPG', 7.46484848484848, 330)
# ('Action, Simulation', 7.059375, 32)
# ('Action, Strategy', 7.6, 1)
# ('Adult, Card', 6.05, 2)
# ('Adventure', 6.86485106382979, 1175)
# ('Adventure, Adult', 4.1, 1)
# ('Adventure, Adventure', 6.68, 5)
# ('Adventure, Compilation', 7.6, 11)
# ('Adventure, Episodic', 8.9, 4)
# ('Adventure, Platformer', 8.6, 1)
# ('Adventure, RPG', 7.83333333333333, 3)
# ('Baseball', 4.5, 1)
# ('Battle', 6.2125, 32)
# ('Board', 6.62586206896552, 116)
# ('Board, Compilation', 6.4, 7)
# ('Card', 6.70740740740741, 108)
# ('Card, Battle', 7.15740740740741, 54)
# ('Card, Compilation', 6.66666666666667, 3)
# ('Card, RPG', 7.88888888888889, 9)
# ('Casino', 5.12903225806452, 31)
# ('Compilation', 7.1, 54)
# ('Compilation, Compilation', 9.5, 1)
# ('Compilation, RPG', 8.2, 2)
# ('Educational', 5.955, 20)
# ('Educational, Action', 6.39090909090909, 11)
# ('Educational, Adventure', 7.16666666666667, 3)
# ('Educational, Card', 5.3, 1)
# ('Educational, Productivity', 4.66, 5)
# ('Educational, Puzzle', 6.912, 25)
# ('Educational, Simulation', 7.0, 2)
# ('Educational, Trivia', 3.0, 2)
# ('Fighting', 7.0581352833638, 547)
# ('Fighting, Action', 6.7012987012987, 77)
# ('Fighting, Adventure', 4.9, 5)
# ('Fighting, Compilation', 7.29230769230769, 13)
# ('Fighting, RPG', 5.8, 2)
# ('Fighting, Simulation', 6.03333333333333, 3)
# ('Flight', 6.7625, 24)
# ('Flight, Action', 6.7312, 125)
# ('Flight, Racing', 7.0, 3)
# ('Flight, Simulation', 7.11891891891892, 37)
# ('Hardware', 9.15, 2)
# ('Hunting', 5.71964285714286, 112)
# ('Hunting, Action', 2.0, 2)
# ('Hunting, Simulation', 7.3, 1)
# ('Music', 6.89407008086254, 371)
# ('Music, Action', 7.66410256410257, 39)
# ('Music, Adventure', 8.8, 1)
# ('Music, Compilation', 6.825, 4)
# ('Music, Editor', 7.91666666666667, 6)
# ('Music, RPG', 8.5, 1)
# ('Other', 5.42, 20)
# ('Other, Action', 9.0, 1)
# ('Other, Adventure', 6.0, 1)
# ('Party', 5.84539007092199, 141)
# ('Pinball', 6.55064935064935, 77)
# ('Pinball, Compilation', 5.5, 1)
# ('Platformer', 7.18651275820171, 823)
# ('Platformer, Action', 8.32727272727273, 11)
# ('Platformer, Adventure', 8.775, 8)
# ('Productivity', 5.93333333333333, 39)
# ('Productivity, Action', 8.0, 2)
# ('Puzzle', 7.08311855670103, 776)
# ('Puzzle, Action', 7.1255, 200)
# ('Puzzle, Adventure', 7.47872340425532, 47)
# ('Puzzle, Compilation', 6.01111111111111, 9)
# ('Puzzle, Platformer', 8.2, 1)
# ('Puzzle, RPG', 9.1, 1)
# ('Puzzle, Word Game', 5.95, 6)
# ('RPG', 7.57142857142859, 980)
# ('RPG, Action', 7.4, 1)
# ('RPG, Compilation', 7.875, 4)
# ('RPG, Editor', 7.6, 2)
# ('RPG, Simulation', 7.1, 8)
# ('Racing', 6.73061889250814, 1228)
# ('Racing, Action', 6.58714285714286, 210)
# ('Racing, Compilation', 7.35, 2)
# ('Racing, Editor', 7.46666666666667, 3)
# ('Racing, Shooter', 8.2, 2)
# ('Racing, Simulation', 8.272, 25)
# ('Shooter', 7.12788819875776, 1610)
# ('Shooter, Adventure', 4.9, 1)
# ('Shooter, First-Person', 8.9, 4)
# ('Shooter, Platformer', 8.23333333333333, 3)
# ('Shooter, RPG', 7.82272727272727, 22)
# ('Simulation', 6.8589065255732, 567)
# ('Simulation, Adventure', 6.0, 1)
# ('Sports', 7.0252087682672, 1916)
# ('Sports, Action', 7.09744897959184, 196)
# ('Sports, Baseball', 7.76666666666667, 3)
# ('Sports, Compilation', 5.87142857142857, 14)
# ('Sports, Editor', 3.0, 1)
# ('Sports, Fighting', 2.7, 1)
# ('Sports, Golf', 5.5, 1)
# ('Sports, Other', 7.2, 1)
# ('Sports, Party', 7.3, 1)
# ('Sports, Racing', 6.88, 5)
# ('Sports, Simulation', 7.79545454545454, 44)
# ('Strategy', 7.24603174603174, 1071)
# ('Strategy, Compilation', 7.0, 1)
# ('Strategy, RPG', 7.85454545454545, 77)
# ('Strategy, Simulation', 8.1, 1)
# ('Trivia', 6.20504201680672, 119)
# ('Virtual Pet', 6.02682926829268, 82)
# ('Wrestling', 7.05820895522388, 134)
# ('Wrestling, Simulation', 7.0, 1)
# (None, 6.74722222222222, 0)

# %% [markdown]
# # Analysis of results:
#
# ## Notice that relatively few game genres actually have average IGN scores exceeding 8, and none of them quite reach 9. Most game genres average a bit above 6 or 7 in terms of IGN scores, and several have scores of less than 4.
#
# ## In terms of the number of games per genre, Action is by far the highest, with over 3,700 games in the dataset (not even including the several sub-genres within Action, such as Action/Adventure). The next-most popular games are Sports and Shooters, each with over 1,500 each (even more, factoring in various sub-genres). Adventure games are also well-represented in the dataset, with over 1,000 games in the dataset, and similar genres such as Action/Adventure are also popular (765 ). .

# %% [markdown]
# # Which games received IGN editors' choice awards? Do the average IGN scores for these games differ substantially with the overall sample average?

# %% [markdown]
# # Select all games' titles, genres, and release years for games that received IGN editors' choice awards:
#
# ## I.e., PostgreSQL SELECT query syntax would be: <<< SELECT title, genre, and release_year FROM ign_ratings WHERE editors_choice_y =1

# %%
#import SQLAlchemy library 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, String, MetaData, Float, Integer, ForeignKey, Boolean

from sqlalchemy import event, select, func

#specify the table so query can be done on it
ign_ratings = Table('ign_ratings', meta,
                      Column('ID', Integer, primary_key=True),
                      Column('score_phrase', String),
                      Column('title', String),
                      Column('url', String),
                      Column('platform', String),
                      Column('score', Float),
                      Column('genre', String),
                      Column('release_year', Integer),
                      Column('release_month', Integer),
                      Column('release_day', Integer),
                      Column('editors_choice_y', Integer),
                   )

#re-specify the password, host, and other info needed to access the database
db_string = "postgres://postgres:*******@localhost:5433/goods"
db_co = create_engine(db_string)

meta = MetaData(db_co)  

with db_co.connect() as conn: 
    # do SELECT statement, and print out its output
    select_statement = select([ign_ratings.c.title, ign_ratings.c.genre, ign_ratings.c.release_year]).where(ign_ratings.c.editors_choice_y == 1)    
    result_set = conn.execute(select_statement)
    for r in result_set:
        print(r)
# Out:
# ('LittleBigPlanet PS Vita', 'Platformer', 2012)
# ('LittleBigPlanet PS Vita -- Marvel Super Hero Edition', 'Platformer', 2012)
# ('Guild Wars 2', 'RPG', 2012)
# ('Mark of the Ninja', 'Action, Adventure', 2012)
# ('Mark of the Ninja', 'Action, Adventure', 2012)
# ('Dark Souls (Prepare to Die Edition)', 'Action, RPG', 2012)
# ('Bastion', 'Action, RPG', 2012)
# ('The Walking Dead: The Game -- Episode 3: Long Road Ahead', 'Adventure', 2012)
# ('World of Warcraft: Mists of Pandaria', 'RPG', 2012)
# ('Pokemon White Version 2', 'RPG', 2012)
# ('Pokemon Black Version 2', 'RPG', 2012)
# ('The Walking Dead: The Game -- Episode 3: Long Road Ahead', 'Adventure', 2012)
# ('The Walking Dead: The Game -- Episode 3: Long Road Ahead', 'Adventure', 2012)
# ('The Walking Dead: The Game -- Episode 3: Long Road Ahead', 'Adventure', 2012)
# ('Rock Band Blitz', 'Music', 2012)
# ('Bad Piggies', 'Action', 2012)
# ('NBA 2K13', 'Sports', 2012)
# ('The World Ends with You: Solo Remix', 'RPG', 2012)
# ('The World Ends with You: Solo Remix', 'RPG', 2012)
# ('Madden NFL 13', 'Sports', 2012)
# ('Madden NFL 13', 'Sports', 2012)
# ('NBA 2K13', 'Sports', 2012)
# ('NBA 2K13', 'Sports', 2012)
# ('Professor Layton and the Miracle Mask', 'Adventure', 2012)
# ('Hotline Miami', 'Action', 2012)
# ('Hero Academy', 'Board', 2012)
# ('Hero Academy', 'Strategy', 2012)
# ('Puzzle Craft', 'Puzzle', 2012)
# ('Puzzle Craft', 'Puzzle', 2012)
# ('Horn', 'Action, Adventure', 2012)
# ('Forza Horizon', 'Racing', 2012)
# ('Punch Quest', 'Action', 2012)
# ('FIFA Soccer 13', 'Sports', 2012)
# ('FIFA Soccer 13', 'Sports', 2012)
# ('Torchlight II', 'Action, RPG', 2012)
# ('FIFA Soccer 13', 'Sports', 2012)
# ('Iron Brigade', 'Action', 2012)
# ("Zero Escape: Virtue's Last Reward", 'Adventure', 2012)
# ("Zero Escape: Virtue's Last Reward", 'Adventure', 2012)
# ('The Walking Dead: The Game -- Episode 3: Long Road Ahead', 'Adventure', 2012)
# ('Pro Evolution Soccer 2013', 'Sports', 2012)
# ('F1 2012', 'Racing', 2012)
# ('Sound Shapes', 'Platformer', 2012)
# ('Sound Shapes', 'Platformer', 2012)
# ('Dishonored', 'Action', 2012)
# ('Dishonored', 'Action', 2012)
# ('Dishonored', 'Action', 2012)
# ('Funky Smugglers', 'Action', 2012)
# ('F1 2012', 'Racing', 2012)
# ('Pro Evolution Soccer 2013', 'Sports', 2012)
# ('F1 2012', 'Racing', 2012)
# ('Pro Evolution Soccer 2013', 'Sports', 2012)
# ('Borderlands 2', 'Shooter, RPG', 2012)
# ('Borderlands 2', 'Shooter, RPG', 2012)
# ('Borderlands 2', 'Shooter, RPG', 2012)
# ('Sound Shapes', 'Platformer', 2012)
# ('Persona 4 Arena', 'Fighting', 2012)
# ('Persona 4 Arena', 'Fighting', 2012)
# ('The Unfinished Swan', 'Puzzle', 2012)
# ('Halo 4', 'Shooter', 2012)
# ('Halo 4 (Limited Edition)', 'Shooter', 2012)
# ('Okami HD', 'Adventure', 2012)
# ('Need for Speed Most Wanted', 'Racing, Action', 2012)
# ('Need for Speed Most Wanted', 'Racing, Action', 2012)
# ('Need for Speed Most Wanted', 'Racing, Action', 2012)
# ('Call of Duty: Black Ops II', 'Shooter', 2012)
# ('Call of Duty: Black Ops II', 'Shooter', 2012)
# ('Call of Duty: Black Ops II', 'Shooter', 2012)
# ('Football Manager 2013', 'Sports, Simulation', 2012)
# ('The Walking Dead: The Game -- Episode 5: No Time Left', 'Adventure', 2012)
# ('The Walking Dead: The Game -- Episode 5: No Time Left', 'Adventure', 2012)
# ('The Walking Dead: The Game -- Episode 5: No Time Left', 'Adventure', 2012)
# ('The Walking Dead: The Game -- Episode 5: No Time Left', 'Adventure', 2012)
# ('Football Manager 2013', 'Sports, Simulation', 2012)
# ('Hitman: Absolution', 'Action', 2012)
# ('Hitman: Absolution', 'Action', 2012)
# ('Hitman: Absolution', 'Action', 2012)
# ('Batman: Arkham City -- Armored Edition', 'Action', 2012)
# ('Scribblenauts Unlimited', 'Puzzle, Action', 2012)
# ('The Walking Dead: A Telltale Game Series -- Season One', 'Adventure', 2012)
# ('New Super Mario Bros. U', 'Platformer', 2012)
# ('Nintendo Land', 'Party', 2012)
# ('The Walking Dead: A Telltale Game Series -- Season One', 'Adventure', 2012)
# ('The Walking Dead -- Game of the Year Edition', 'Adventure', 2012)
# ('The Walking Dead: A Telltale Game Series -- Season One', 'Adventure', 2012)
# ('Crashmo', 'Puzzle, Action', 2012)
# ('PlanetSide 2', 'Shooter', 2012)
# ('The Walking Dead: A Telltale Game Series -- Season One', 'Adventure', 2012)
# ('The Walking Dead: A Telltale Game Series -- Season One', 'Adventure', 2012)
# ('Ni no Kuni: Wrath of the White Witch', 'RPG', 2013)
# ("Assassin's Creed III", 'Action, Adventure', 2012)
# ("Adventure Time: Hey Ice King! Why'd You Steal Our Garbage?", 'Adventure', 2012)
# ('The Walking Dead -- Game of the Year Edition', 'Adventure', 2012)
# ('The Walking Dead -- Game of the Year Edition', 'Adventure', 2012)
# ('The Walking Dead: A Telltale Game Series -- Season One', 'Adventure', 2012)
# ('Minigore 2: Zombies', 'Shooter', 2012)
# ('DmC: Devil May Cry', 'Action', 2013)
# ('DmC: Devil May Cry', 'Action', 2013)
# ('Persona 4 Golden', 'RPG', 2012)
# ('Call of Duty: Black Ops II', 'Shooter', 2012)
# ('Far Cry 3', 'Shooter', 2012)
# ('Far Cry 3', 'Shooter', 2012)
# ("Trine 2: Director's Cut", 'Action', 2012)
# ('Mass Effect', 'RPG', 2012)
# ('Joe Danger', 'Action', 2013)
# ('DmC: Devil May Cry', 'Action', 2013)
# ('Mutant Mudds', 'Platformer', 2013)
# ('Far Cry 3', 'Shooter', 2012)
# ('Nano Assault Neo', 'Shooter', 2012)
# ("Borderlands 2: Mr. Torgue's Campaign of Carnage", 'Shooter, RPG', 2012)
# ('Scribblenauts Unlimited', 'Puzzle, Action', 2012)
# ("Borderlands 2: Mr. Torgue's Campaign of Carnage", 'Shooter, RPG', 2012)
# ("Borderlands 2: Mr. Torgue's Campaign of Carnage", 'Shooter, RPG', 2012)
# ('NBA 2K13', 'Sports', 2012)
# ('The Walking Dead: The Game -- Episode 5: No Time Left', 'Adventure', 2012)
# ('WipEout XL', 'Racing', 1996)
# ('Tobal No. 1', 'Fighting', 1996)
# ('X-COM: UFO Defense', 'Strategy', 1996)
# ('Wave Race 64', 'Racing', 1996)
# ('Tekken 2', 'Fighting', 1996)
# ('Super Mario 64', 'Platformer', 1996)
# ('Mario Kart 64', 'Racing, Action', 1997)
# ('Blood Omen: Legacy of Kain', 'Action, RPG', 1997)
# ('Super Puzzle Fighter II Turbo', 'Puzzle, Action', 1997)
# ('Blast Corps', 'Action', 1997)
# ("NBA ShootOut '97", 'Sports', 1997)
# ('Soul Blade', 'Fighting', 1997)
# ('Tobal No. 1', 'Fighting', 1996)
# ('WipEout XL', 'Racing', 1996)
# ('NFL GameDay 98', 'Sports', 1997)
# ('GoldenEye 007', 'Shooter', 1997)
# ('Ace Combat 2', 'Flight, Action', 1997)
# ('Time Crisis', 'Action', 1997)
# ('1080° Snowboarding', 'Sports', 1998)
# ('Colony Wars', 'Action', 1997)
# ('Poy Poy', 'Action', 1997)
# ('Bushido Blade', 'Fighting', 1997)
# ('Dead or Alive', 'Fighting', 1998)
# ('Final Fantasy VII', 'RPG', 1997)
# ('Klonoa: Door to Phantomile', 'Platformer', 1998)
# ('Final Fantasy Tactics', 'Strategy, RPG', 1998)
# ('Resident Evil 2 [1998]', 'Action, Adventure', 1998)
# ('Castlevania: Symphony of the Night', 'Action, Adventure', 1997)
# ('Alundra', 'Action, RPG', 1998)
# ('Parappa The Rapper', 'Music', 1997)
# ('Hot Shots Golf', 'Sports, Action', 1998)
# ('Banjo-Kazooie', 'Platformer', 1998)
# ('Grim Fandango', 'Adventure', 1998)
# ('Metal Gear Solid', 'Action, Adventure', 1998)
# ('Xenogears', 'RPG', 1998)
# ("NHL '99", 'Sports', 1998)
# ('F-Zero X', 'Racing', 1998)
# ("Tom Clancy's Rainbow Six", 'Shooter', 1998)
# ('Unreal', 'Shooter', 1998)
# ('The Operational Art of War, Vol. 1', 'Strategy', 1998)
# ('Might and Magic VI: The Mandate of Heaven', 'RPG', 1998)
# ('Railroad Tycoon II', 'Strategy', 1998)
# ('Space Station Silicon Valley', 'Platformer', 1998)
# ('Caesar III', 'Strategy', 1998)
# ('Devil Dice', 'Puzzle', 1998)
# ('Tomba!', 'Platformer', 1998)
# ('Elemental Gearbolt', 'Action', 1998)
# ('Need for Speed III: Hot Pursuit', 'Racing', 1998)
# ('Moto Racer 2', 'Racing', 1998)
# ('Tenchu: Stealth Assassins', 'Action', 1998)
# ('Einhander', 'Shooter', 1998)
# ('Gran Turismo [1998]', 'Racing', 1998)
# ('Tekken 3', 'Fighting', 1998)
# ('Fallout 2', 'RPG', 1998)
# ('Delta Force', 'Shooter', 1998)
# ('Shogo: Mobile Armor Division', 'Action', 1998)
# ('Colony Wars: Vengeance', 'Action', 1998)
# ("International Superstar Soccer '98", 'Sports', 1998)
# ('Crash Bandicoot: Warped', 'Platformer', 1998)
# ('Thief: The Dark Project', 'Action', 1998)
# ('Star Wars: Rogue Squadron', 'Flight, Action', 1998)
# ("FIFA '99", 'Sports', 1998)
# ('Half-Life', 'Shooter', 1998)
# ('Bust A Groove', 'Music, Action', 1998)
# ('The Legend of Zelda: Ocarina of Time', 'Action, Adventure', 1998)
# ('Street Fighter Collection 2', 'Fighting, Compilation', 1998)
# ('Close Combat III: The Russian Front', 'Strategy', 1999)
# ("Baldur's Gate", 'RPG', 1999)
# ('Moto Racer 2', 'Racing', 1999)
# ('Starsiege: Tribes', 'Shooter', 1999)
# ("Oddworld: Abe's Exoddus", 'Platformer', 1999)
# ('Powerslide', 'Racing', 1998)
# ('Myth II: Soulblighter', 'Strategy', 1999)
# ('Silent Hill', 'Adventure', 1999)
# ('SimCity 3000', 'Simulation', 1999)
# ('Syphon Filter', 'Action', 1999)
# ("Sid Meier's Alpha Centauri", 'Strategy', 1999)
# ('Heroes of Might and Magic III: The Restoration of Erathia', 'Strategy', 1999)
# ('EverQuest', 'RPG', 1999)
# ('Beetle Adventure Racing', 'Racing', 1999)
# ('Need for Speed: High Stakes', 'Racing', 1999)
# ('Super Smash Bros.', 'Fighting', 1999)
# ('Falcon 4.0', 'Simulation', 1999)
# ('High Heat Baseball 2000', 'Sports', 1999)
# ('RollerCoaster Tycoon', 'Simulation', 1999)
# ('Street Fighter Alpha 3', 'Fighting', 1999)
# ('Point Blank 2', 'Shooter', 1999)
# ('R4: Ridge Racer Type 4', 'Racing', 1999)
# ('MechWarrior 3', 'Simulation', 1999)
# ('Bloody Roar II: The New Breed', 'Fighting', 1999)
# ('The Next Tetris', 'Puzzle', 1999)
# ('Ape Escape', 'Platformer', 1999)
# ('Pokemon Blue Version', 'RPG', 1999)
# ('Pokemon Red Version', 'RPG', 1999)
# ('World Driver Championship', 'Racing', 1999)
# ('Descent 3', 'Shooter', 1999)
# ('Midtown Madness', 'Racing', 1999)
# ('Worms Armageddon', 'Strategy', 1999)
# ('Dungeon Keeper II', 'Strategy', 1999)
# ('Driver', 'Racing, Action', 1999)
# ('Super Mario Bros. Deluxe', 'Platformer', 1999)
# ('Metal Slug: First Mission', 'Action', 1999)
# ('Soulcalibur', 'Fighting', 1999)
# ('Legacy of Kain: Soul Reaver', 'Adventure', 1999)
# ("The Legend of Zelda: Link's Awakening DX", 'Action, Adventure', 1999)
# ('Darkstone', 'RPG', 1999)
# ('Final Fantasy VIII', 'RPG', 1999)
# ('Jagged Alliance 2', 'Strategy', 1999)
# ('Sled Storm', 'Racing', 1999)
# ('System Shock 2', 'RPG', 1999)
# ('Re-Volt', 'Racing', 1999)
# ('Legacy of Kain: Soul Reaver', 'Adventure', 1999)
# ('Um Jammer Lammy', 'Music, Action', 1999)
# ('Madden NFL 2000', 'Sports', 1999)
# ('Dino Crisis', 'Adventure', 1999)
# ('Championship Motocross Featuring Ricky Carmichael', 'Racing', 1999)
# ('Marvel vs. Capcom: Clash of Super Heroes', 'Fighting', 1999)
# ("Tom Clancy's Rainbow Six: Rogue Spear", 'Action', 1999)
# ('WipEout 3', 'Racing', 1999)
# ('Mario Golf [Game Boy Color]', 'Sports, Action', 1999)
# ('Age of Empires II: The Age of Kings', 'Strategy', 1999)
# ('Jet Force Gemini', 'Shooter', 1999)
# ('NHL 2000', 'Sports', 1999)
# ('Driver', 'Racing, Action', 1999)
# ('Monster Rancher 2', 'Simulation', 1999)
# ('Final Fantasy Anthology', 'RPG', 1999)
# ('Homeworld', 'Strategy', 1999)
# ('FreeSpace 2', 'Action', 1999)
# ('Pharaoh', 'Strategy', 1999)
# ('Resident Evil 3: Nemesis', 'Action, Adventure', 1999)
# ("You Don't Know Jack! [1999]", 'Trivia', 1999)
# ('Suikoden II', 'RPG', 1999)
# ('FIFA 2000 Major League Soccer', 'Sports', 1999)
# ("Sid Meier's Alien Crossfire", 'Strategy', 1999)
# ('Ms. Pac-Man', 'Action', 1999)
# ('NHL Championship 2000', 'Sports', 1999)
# ("Tony Hawk's Pro Skater", 'Sports', 1999)
# ('Flight Unlimited III', 'Simulation', 1999)
# ('Resident Evil 2 [1998]', 'Action, Adventure', 1999)
# ('WWF Wrestlemania 2000', 'Wrestling', 1999)
# ('Pong: The Next Level', 'Action', 1999)
# ('Grandia', 'RPG', 1999)
# ('Rayman 2: The Great Escape', 'Platformer', 1999)
# ('Rayman 2: The Great Escape', 'Platformer', 1999)
# ('Rocket: Robot on Wheels', 'Platformer', 1999)
# ('Knockout Kings 2000', 'Sports', 1999)
# ('FIFA 2000 Major League Soccer', 'Sports', 1999)
# ('Crash Team Racing', 'Racing, Action', 1999)
# ('Medal of Honor [1999]', 'Action', 1999)
# ('NASCAR Racing 3', 'Racing', 1999)
# ('NERF Arena Blast', 'Action', 1999)
# ("Heroes of Might and Magic III: Armageddon's Blade", 'Strategy', 1999)
# ('Quake III: Arena', 'Shooter', 1999)
# ('Re-Volt', 'Racing', 1999)
# ('NBA Live 2000', 'Sports', 1999)
# ('SWAT 3: Close Quarters Battle', 'Action', 1999)
# ('Unreal Tournament [1999]', 'Shooter', 1999)
# ('NBA Courtside 2: Featuring Kobe Bryant', 'Sports', 1999)
# ('Shadow Man', 'Action', 1999)
# ('Age of Wonders', 'Strategy', 1999)
# ('Worms Armageddon', 'Puzzle', 1999)
# ('Rampart', 'Strategy', 1999)
# ('Harvest Moon 64', 'RPG', 1999)
# ('NCAA March Madness 2000', 'Sports', 1999)
# ("SNK vs. Capcom: Card Fighter's Clash", 'Card, Battle', 2000)
# ('Crazy Taxi', 'Racing, Action', 2000)
# ('Planescape: Torment', 'RPG', 1999)
# ('Shanghai: Second Dynasty', 'Puzzle', 2000)
# ("Sid Meier's Antietam!", 'Strategy', 2000)
# ('Shanghai Pocket', 'Puzzle', 2000)
# ('Gran Turismo 2', 'Racing', 1999)
# ('Dragon Warrior Monsters', 'RPG', 2000)
# ('NASCAR Legends', 'Racing', 2000)
# ('Tomba! 2 -- The Evil Swine Return', 'Platformer', 2000)
# ('Legacy of Kain: Soul Reaver', 'Action', 2000)
# ('Dirt Track Racing', 'Racing', 1999)
# ('MiG Alley', 'Simulation', 2000)
# ('SNK vs. Capcom: Match of the Millennium', 'Fighting', 2000)
# ('Descent 3: Mercenary', 'Shooter', 2000)
# ('MTV Music Generator', 'Music, Editor', 2000)
# ('Silhouette Mirage', 'Action', 2000)
# ('The Sims', 'Simulation', 2000)
# ("Formula 1 '99", 'Racing', 2000)
# ('WWF Smackdown!', 'Wrestling', 2000)
# ('Magical Tetris Challenge', 'Puzzle, Adventure', 2000)
# ('Nox', 'Action', 2000)
# ('Colin McRae Rally [2000]', 'Racing', 2000)
# ('Fear Effect', 'Action, Adventure', 2000)
# ('Thief II: The Metal Age', 'Action', 2000)
# ('Rayman 2: The Great Escape', 'Platformer', 2000)
# ('Front Mission 3', 'RPG', 2000)
# ('Mobil 1 Rally Championship', 'Racing', 2000)
# ('Chu Chu Rocket', 'Puzzle', 2000)
# ('Syphon Filter 2', 'Action', 2000)
# ("Tony Hawk's Pro Skater", 'Sports', 2000)
# ('Hot Shots Golf 2', 'Sports, Action', 2000)
# ('Ace Combat 3: Electrosphere', 'Action', 2000)
# ('Soldier of Fortune', 'Action', 2000)
# ('Resident Evil -- CODE: Veronica', 'Action, Adventure', 2000)
# ('MDK2', 'Action', 2000)
# ('All-Star Baseball 2001', 'Sports', 2000)
# ('Bomberman Max -- Red: Challenger', 'Action', 2000)
# ("Tony Hawk's Pro Skater", 'Sports', 2000)
# ('Starlancer', 'Action', 2000)
# ('Metal Gear Solid [2000]', 'Action, Adventure', 2000)
# ('Vagrant Story', 'RPG', 2000)
# ('Perfect Dark', 'Shooter', 2000)
# ('Street Fighter Alpha 3', 'Fighting', 2000)
# ('Heroes of Might and Magic III: Shadow of Death', 'Strategy', 2000)
# ('Silent Bomber', 'Action', 2000)
# ('Speed Punks', 'Racing', 2000)
# ('Imperium Galactica II: Alliances', 'Strategy', 2000)
# ('EverQuest: Ruins of Kunark', 'RPG', 2000)
# ("JoJo's Bizarre Adventure", 'Fighting', 2000)
# ('Excitebike 64', 'Racing', 2000)
# ('Metal Slug: 2nd Mission', 'Action', 2000)
# ('Earth 2150', 'Strategy', 2000)
# ('Ground Control', 'Strategy', 2000)
# ('Deus Ex', 'RPG', 2000)
# ('Icewind Dale', 'RPG', 2000)
# ('StarCraft', 'Strategy', 2000)
# ('Legend of Mana', 'RPG', 2000)
# ('SimCity 3000 Unlimited', 'Simulation', 2000)
# ('Diablo II', 'Action, RPG', 2000)
# ('Virtua Tennis', 'Sports', 2000)
# ('Shogun: Total War', 'Strategy', 2000)
# ('Marvel vs. Capcom 2: New Age of Heroes', 'Fighting', 2000)
# ('Colony Wars: Red Sun', 'Action', 2000)
# ('Mario Tennis', 'Sports, Action', 2000)
# ('Strider 2', 'Action', 2000)
# ('Pharaoh: Cleopatra', 'Strategy', 2000)
# ('Field & Stream Trophy Bass 4', 'Hunting', 2000)
# ('F-Zero X Expansion Kit', 'Productivity', 2000)
# ('Madden NFL 2001', 'Sports', 2000)
# ('Chrono Cross', 'RPG', 2000)
# ('Tenchu 2: Birth of the Stealth Assassins', 'Action', 2000)
# ('Tokyo Xtreme Racer 2', 'Racing', 2000)
# ('Michelin Rally Masters Race of Champions', 'Racing', 2000)
# ('Frogger 2', 'Action', 2000)
# ('Metal Gear Solid', 'Action, Adventure', 2000)
# ('Dino Crisis 2', 'Adventure', 2000)
# ('Crimson Skies', 'Action', 2000)
# ('San Francisco Rush 2049', 'Racing', 2000)
# ('NFL 2K1', 'Sports', 2000)
# ('San Francisco Rush 2049', 'Racing', 2000)
# ('MindRover: The Europa Project', 'Simulation', 2000)
# ('Ultimate Fighting Championship', 'Fighting', 2000)
# ('Enemy Engaged: Comanche vs. Hokum', 'Simulation', 2000)
# ('Grand Prix 3', 'Racing', 2000)
# ('Ferrari F355 Challenge', 'Racing, Simulation', 2000)
# ("Tony Hawk's Pro Skater 2", 'Sports', 2000)
# ('Return of The Incredible Machine: Contraptions', 'Puzzle', 2000)
# ('Spider-Man [2000]', 'Action', 2000)
# ('Power Stone 2', 'Fighting, Action', 2000)
# ('Wizards & Warriors [2000]', 'RPG', 2000)
# ('Madden NFL 2001', 'Sports', 2000)
# ('Rayman 2: The Great Escape', 'Platformer', 2000)
# ('Midtown Madness 2', 'Racing', 2000)
# ('Valkyrie Profile', 'RPG', 2000)
# ('Homeworld: Cataclysm', 'Strategy', 2000)
# ('TimeSplitters', 'Shooter', 2000)
# ('FIFA 2001: Major League Soccer', 'Sports', 2000)
# ('Madden NFL 2001', 'Sports', 2000)
# ('Unreal Tournament [1999]', 'Shooter', 2000)
# ('Pokemon Gold Version', 'RPG', 2000)
# ('NBA Live 2001', 'Sports', 2000)
# ('007: The World is Not Enough', 'Shooter', 2000)
# ('Spyro: Year of the Dragon', 'Platformer', 2000)
# ('Superbike 2001', 'Racing', 2000)
# ('SSX [2000]', 'Sports', 2000)
# ('Tekken Tag Tournament', 'Fighting', 2000)
# ("Tony Hawk's Pro Skater 2", 'Sports', 2000)
# ('Test Drive V-Rally', 'Racing', 2000)
# ('Samba de Amigo', 'Music', 2000)
# ('NASCAR Heat', 'Racing', 2000)
# ("Baldur's Gate II: Shadows of Amn", 'RPG', 2000)
# ('Rollcage Stage II', 'Racing', 2000)
# ('Pokemon Silver Version', 'RPG', 2000)
# ('Ogre Battle 64: Person of Lordly Caliber', 'Strategy', 2000)
# ('NHL 2001', 'Sports', 2000)
# ('Jet Grind Radio', 'Action', 2000)
# ('Death Track Racing', 'Racing', 2000)
# ('Donkey Kong Country', 'Platformer', 2000)
# ('WWF Smackdown! 2: Know Your Role', 'Wrestling', 2000)
# ("You Don't Know Jack, Mock 2", 'Trivia', 2000)
# ("The Legend of Zelda: Majora's Mask", 'Action, Adventure', 2000)
# ('Command & Conquer: Red Alert 2', 'Strategy', 2000)
# ('Spider-Man [2000]', 'Adventure', 2000)
# ('Test Drive Le Mans', 'Racing', 2000)
# ("Tony Hawk's Pro Skater 2", 'Sports', 2000)
# ('Midnight Club: Street Racing', 'Racing', 2000)
# ('Quake III: Arena', 'Shooter', 2000)
# ('Banjo-Tooie', 'Platformer', 2000)
# ('The Longest Journey', 'Adventure', 2000)
# ('Shenmue', 'Action, RPG', 2000)
# ('Zeus: Master of Olympus', 'Strategy', 2000)
# ('Sky Odyssey', 'Flight, Simulation', 2000)
# ('Sacrifice', 'Strategy', 2000)
# ("The Jungle Book: Mowgli's Wild Adventure", 'Platformer', 2000)
# ('No One Lives Forever', 'Shooter', 2000)
# ('Medal of Honor Underground', 'Action', 2000)
# ('SWAT 3: Elite Edition', 'Action', 2000)
# ('RayCrisis', 'Shooter', 2000)
# ('Pac-Man: Adventures in Time', 'Platformer', 2000)
# ('RC de GO!', 'Racing, Simulation', 2000)
# ('Skies of Arcadia', 'RPG', 2000)
# ('Escape From Monkey Island', 'Adventure', 2000)
# ('WWF No Mercy', 'Wrestling', 2000)
# ('Sin and Punishment: Successor to the Earth', 'Shooter', 2000)
# ('Incredible Crisis', 'Other', 2000)
# ('Sea Dogs', 'RPG', 2000)
# ('Starlancer', 'Action', 2000)
# ('Final Fantasy IX', 'RPG', 2000)
# ('Counter-Strike', 'Shooter', 2000)
# ('Napple Tale: Arsia in Daydream', 'Action, Adventure', 2000)
# ('FIFA 2001: Major League Soccer', 'Sports', 2000)
# ('MechWarrior 4: Vengeance', 'Simulation', 2000)
# ('Looney Tunes: Space Race', 'Action', 2000)
# ('Micro Machines V3', 'Racing', 2000)
# ("American McGee's Alice", 'Action', 2000)
# ('FIFA 2001: Major League Soccer', 'Sports', 2000)
# ('The Grinch', 'Action', 2000)
# ('Grandia II', 'RPG', 2000)
# ('NCAA March Madness 2001', 'Sports', 2000)
# ('Giants: Citizen Kabuto', 'Action', 2000)
# ('Metropolis Street Racer', 'Racing', 2001)
# ('Last Blade 2: Final Edition', 'Fighting', 2001)
# ('Star Wars: Battle for Naboo', 'Flight, Action', 2000)
# ('Indiana Jones and the Infernal Machine', 'Action', 2000)
# ('Virtual Pool 3 Featuring Jeanette Lee', 'Sports', 2000)
# ('EverQuest: The Scars of Velious', 'RPG', 2000)
# ('Space Empires IV', 'Strategy', 2001)
# ('Bangai-O', 'Shooter', 2001)
# ('F1 Championship Season 2000', 'Racing', 2001)
# ('Pokemon Puzzle Challenge', 'Puzzle', 2000)
# ("Dragon's Lair", 'Action', 2001)
# ('The Chessmaster 8000', 'Board', 2000)
# ('Samba de Amigo Ver. 2000', 'Music', 2001)
# ('Guilty Gear X', 'Fighting', 2001)
# ('Persona 2: Eternal Punishment', 'RPG', 2000)
# ('Colin McRae Rally 2.0', 'Racing', 2000)
# ('Moto Racer World Tour', 'Racing', 2000)
# ('Blade of Darkness', 'Action', 2001)
# ('Star Wars Starfighter', 'Flight, Action', 2001)
# ('Cannon Fodder', 'Action', 2001)
# ("Clive Barker's Undying", 'Action', 2001)
# ('Final Fantasy', 'RPG', 2001)
# ('Knockout Kings 2001', 'Sports', 2001)
# ('SimCoaster', 'Simulation', 2001)
# ('Phantasy Star Online', 'RPG', 2001)
# ('Colin McRae Rally 2.0', 'Racing', 2001)
# ('ATV Offroad Fury', 'Racing', 2001)
# ('Paper Mario', 'RPG', 2001)
# ('Rayman 2: Revolution', 'Platformer', 2001)
# ('Mega Man X5', 'Action', 2001)
# ('Steel Beasts', 'Simulation', 2001)
# ('Mario Tennis [2001]', 'Sports, Action', 2001)
# ('The Typing of the Dead', 'Educational, Action', 2001)
# ('Ring of Red', 'Strategy', 2001)
# ('NASCAR Racing 4', 'Racing', 2001)
# ('Shadow of Destiny', 'Adventure', 2001)
# ("Conker's Bad Fur Day", 'Action, Adventure', 2001)
# ('Icewind Dale: Heart of Winter', 'RPG', 2001)
# ('Black & White', 'Strategy', 2001)
# ('Europa Universalis', 'Strategy', 2001)
# ('All-Star Baseball 2002', 'Sports', 2001)
# ('Crazy Taxi 2', 'Racing, Action', 2001)
# ('Red Faction', 'Shooter', 2001)
# ('Daytona USA', 'Racing', 2001)
# ('Onimusha: Warlords', 'Action, Adventure', 2001)
# ('Confidential Mission', 'Shooter', 2001)
# ('The Legend of Zelda: Oracle of Ages', 'Action, Adventure', 2001)
# ('The Legend of Zelda: Oracle of Seasons', 'Action, Adventure', 2001)
# ('Rumble Racing', 'Racing', 2001)
# ('Unreal Tournament [1999]', 'Shooter', 2001)
# ('Tropico', 'Strategy', 2001)
# ('Project Justice', 'Fighting', 2001)
# ('Evil Islands: Curse of the Lost Soul', 'RPG', 2001)
# ('High Heat Major League Baseball 2002', 'Sports', 2001)
# ('Dance Dance Revolution [2001]', 'Music', 2001)
# ('Kohan: Immortal Sovereigns', 'Strategy', 2001)
# ('Serious Sam: The First Encounter', 'Shooter', 2001)
# ('Metal Slug X', 'Shooter', 2001)
# ('MDK2 Armageddon', 'Action', 2001)
# ('Quake III: Revolution', 'Shooter', 2001)
# ("Kirby Tilt 'n' Tumble", 'Action', 2001)
# ("Mickey's Speedway USA", 'Racing', 2001)
# ('Starsiege: Tribes 2', 'Action', 2001)
# ("Tony Hawk's Pro Skater 2", 'Sports', 2001)
# ('F-Zero: Maximum Velocity', 'Racing', 2001)
# ('Spider-Man 2: The Sinister Six', 'Action', 2001)
# ('Startopia', 'Strategy', 2001)
# ('Escape From Monkey Island', 'Adventure', 2001)
# ('Time Crisis: Project Titan', 'Action', 2001)
# ('NBA Street', 'Sports', 2001)
# ('Twisted Metal: Black', 'Shooter', 2001)
# ('Namco Museum', 'Action', 2001)
# ('Tomb Raider: Curse of the Sword', 'Action', 2001)
# ('Diablo II: Lord of Destruction', 'Action, RPG', 2001)
# ('Rayman Advance', 'Platformer', 2001)
# ('Zeus -- Official Expansion: Poseidon', 'Strategy', 2001)
# ("Baldur's Gate II: Throne of Bhaal", 'RPG', 2001)
# ('Castlevania: Circle of the Moon', 'Action, Adventure', 2001)
# ('Chu Chu Rocket', 'Puzzle', 2001)
# ('Sonic Adventure 2', 'Platformer', 2001)
# ('Max Payne', 'Action', 2001)
# ('NCAA Football 2002', 'Sports', 2001)
# ("Klonoa 2: Lunatea's Veil", 'Platformer', 2001)
# ('Dragon Warrior III', 'RPG', 2001)
# ('Final Fantasy Chronicles', 'RPG', 2001)
# ('Pac-Man Collection', 'Action', 2001)
# ('Operation Flashpoint: Cold War Crisis', 'Shooter', 2001)
# ('Mario Kart Super Circuit', 'Racing, Action', 2001)
# ('Arcanum: Of Steamworks and Magick Obscura', 'RPG', 2001)
# ('Shogun: Total War -- The Mongol Invasion', 'Strategy', 2001)
# ('Madden NFL 2002', 'Sports', 2001)
# ('Conquest: Frontier Wars', 'Strategy', 2001)
# ('World Series Baseball 2K2', 'Sports', 2001)
# ('Gran Turismo 3 A-spec', 'Racing, Simulation', 2001)
# ('Last Blade 2: Heart of the Samurai', 'Fighting', 2001)
# ('Outtrigger', 'Action', 2001)
# ('Pokemon Crystal Version', 'RPG', 2001)
# ('Silent Hill 2', 'Adventure', 2001)
# ('NHL 2002', 'Sports', 2001)
# ('NFL 2K2', 'Sports', 2001)
# ('Tales of Destiny II', 'RPG', 2001)
# ('Ooga Booga', 'Action', 2001)
# ('Phantasy Star Online Version 2', 'RPG', 2001)
# ('Time Crisis II', 'Shooter', 2001)
# ('Guilty Gear X', 'Fighting', 2001)
# ('SpyHunter', 'Racing, Action', 2001)
# ('Red Faction', 'Shooter', 2001)
# ('NHL 2002', 'Sports', 2001)
# ('Klonoa: Empire of Dreams', 'Platformer', 2001)
# ('Advance Wars', 'Strategy', 2001)
# ('ICO', 'Adventure', 2001)
# ('Devil May Cry', 'Action, Adventure', 2001)
# ('Project Eden', 'Action, Adventure', 2001)
# ("Victorious Boxers: Ippo's Road to Glory", 'Sports', 2001)
# ('Splashdown', 'Racing', 2001)
# ("Smuggler's Run 2: Hostile Territory", 'Racing', 2001)
# ("Command & Conquer: Yuri's Revenge -- Red Alert 2 Expansion", 'Strategy', 2001)
# ('Commandos 2: Men of Courage', 'Strategy', 2001)
# ('SSX Tricky', 'Sports', 2001)
# ('Burnout', 'Racing', 2001)
# ('Dark Age of Camelot', 'RPG', 2001)
# ("Tony Hawk's Pro Skater 3", 'Sports', 2001)
# ("Sid Meier's Civilization III", 'Strategy', 2001)
# ('Tennis 2K2', 'Sports', 2001)
# ('NBA 2K2', 'Sports', 2001)
# ('FIFA Soccer 2002', 'Sports', 2001)
# ('Soul Reaver 2: Legacy of Kain', 'Action, Adventure', 2001)
# ('Doom (1993)', 'Shooter', 2001)
# ("Dragon Warrior Monsters 2: Tara's Adventure", 'RPG', 2001)
# ('Stronghold', 'Strategy', 2001)
# ('MechWarrior 4: Black Knight', 'Action, Simulation', 2001)
# ("Dragon Warrior Monsters 2: Cobi's Journey", 'RPG', 2001)
# ('Ace Combat 4: Shattered Skies', 'Flight, Action', 2001)
# ('Toki Tori', 'Puzzle, Action', 2001)
# ('Boxing Fever', 'Sports', 2001)
# ('Grand Theft Auto III', 'Action, Adventure', 2001)
# ('Dead or Alive 3', 'Fighting', 2001)
# ("Tony Hawk's Pro Skater 2", 'Sports', 2001)
# ('Golden Sun', 'RPG', 2001)
# ("Tony Hawk's Pro Skater 3", 'Sports', 2001)
# ("Tom Clancy's Ghost Recon", 'Action', 2001)
# ('Project Gotham Racing', 'Racing', 2001)
# ('Halo: Combat Evolved', 'Shooter', 2001)
# ('Madden NFL 2002', 'Sports', 2001)
# ('Myth III: The Wolf Age', 'Strategy', 2001)
# ('Microsoft Flight Simulator 2002', 'Flight, Simulation', 2001)
# ('Star Wars Rogue Squadron II: Rogue Leader', 'Flight, Action', 2001)
# ("Tony Hawk's Pro Skater 3", 'Sports', 2001)
# ('Madden NFL 2002', 'Sports', 2001)
# ('Metal Gear Solid 2: Sons of Liberty', 'Action', 2001)
# ('Half-Life', 'Action', 2001)
# ('Harvest Moon: Save the Homeland', 'RPG', 2001)
# ('NFL 2K2', 'Sports', 2001)
# ('Bomberman Online', 'Action', 2001)
# ('Europa Universalis II', 'Strategy', 2001)
# ('Wario Land 4', 'RPG', 2001)
# ('Wave Race: Blue Storm', 'Racing', 2001)
# ('Jak and Daxter: The Precursor Legacy', 'Platformer', 2001)
# ('Super Bust-A-Move', 'Puzzle', 2001)
# ("Baldur's Gate: Dark Alliance", 'Action, RPG', 2001)
# ('Pikmin', 'Strategy', 2001)
# ('Super Smash Bros. Melee', 'Fighting', 2001)
# ('Ecks vs. Sever', 'Shooter', 2001)
# ('Return to Castle Wolfenstein', 'Shooter', 2001)
# ('Empire Earth', 'Strategy', 2001)
# ('Dynasty Warriors 3', 'Action', 2001)
# ('FIFA Soccer 2002', 'Sports', 2001)
# ('XG3 Extreme-G Racing', 'Racing', 2001)
# ('Dragon Warrior VII', 'RPG', 2001)
# ('Frequency', 'Music, Action', 2001)
# ('Amped: Freestyle Snowboarding', 'Sports', 2001)
# ('Battle Realms', 'Strategy', 2001)
# ('TransWorld Surf', 'Sports', 2001)
# ('Fatal Fury: Mark of The Wolves', 'Fighting', 2001)
# ('NHL 2002', 'Sports', 2001)
# ('F1 2001', 'Racing, Simulation', 2001)
# ('Max Payne', 'Action', 2001)
# ('SSX Tricky', 'Sports', 2001)
# ('NBA 2K2', 'Sports', 2002)
# ('Soul Reaver 2: Legacy of Kain', 'Adventure', 2001)
# ('Tekken Advance', 'Action', 2002)
# ('EverQuest: Shadows of Luclin', 'RPG', 2001)
# ('Final Fantasy X', 'RPG', 2001)
# ('SimGolf', 'Sports', 2002)
# ('Disciples II: Dark Prophecy', 'Strategy', 2002)
# ('Baseball Mogul 2002', 'Sports, Simulation', 2002)
# ('Rampage: Puzzle Attack', 'Puzzle', 2001)
# ('High Heat Major League Baseball 2003', 'Sports', 2002)
# ('Maximo: Ghosts to Glory', 'Action, Adventure', 2002)
# ('Rez', 'Music', 2002)
# ('Headhunter', 'Action', 2002)
# ('Silent Hill 2: Restless Dreams', 'Adventure', 2002)
# ('NBA Inside Drive 2002', 'Sports', 2002)
# ('NHL 2K2', 'Sports', 2002)
# ('Super Mario Advance 2: Super Mario World', 'Platformer', 2002)
# ('Medal of Honor: Allied Assault', 'Shooter', 2002)
# ("Trevor Chan's Capitalism II", 'Simulation', 2002)
# ('WWF Raw [2002]', 'Wrestling', 2002)
# ('Wreckless: The Yakuza Missions', 'Racing', 2002)
# ('NASCAR Racing 2002 Season', 'Racing', 2002)
# ('Serious Sam: The Second Encounter', 'Shooter', 2002)
# ('Sonic Advance', 'Platformer', 2002)
# ('NBA 2K2', 'Sports', 2002)
# ('Doubutsu no Mori', 'Adventure', 2002)
# ('NBA Street', 'Sports', 2002)
# ('Gitaroo-Man', 'Music, Action', 2002)
# ('Jet Set Radio Future', 'Action', 2002)
# ("Tony Hawk's Pro Skater 3", 'Sports', 2002)
# ("Tony Hawk's Pro Skater 3", 'Sports', 2002)
# ('Star Trek: Bridge Commander', 'Simulation', 2002)
# ('Puyo Pop', 'Puzzle', 2002)
# ('Knockout Kings 2002', 'Sports', 2002)
# ('GunValkyrie', 'Action', 2002)
# ('Tropico: Paradise Island', 'Simulation', 2002)
# ('Crash Bandicoot: The Huge Adventure', 'Platformer', 2002)
# ('All-Star Baseball 2003', 'Sports', 2002)
# ('All-Star Baseball 2003', 'Sports', 2002)
# ('RalliSport Challenge', 'Racing', 2002)
# ('Sled Storm', 'Racing', 2002)
# ('Warlords Battlecry II', 'Strategy', 2002)
# ('Star Wars Jedi Starfighter', 'Flight, Action', 2002)
# ('Knockout Kings 2002', 'Sports', 2002)
# ('All-Star Baseball 2003', 'Sports', 2002)
# ('Star Wars Jedi Knight II: Jedi Outcast', 'Action', 2002)
# ("Tom Clancy's Ghost Recon: Desert Siege", 'Shooter', 2002)
# ("Konami Collector's Series: Arcade Advanced", 'Action', 2002)
# ('Freedom Force', 'RPG', 2002)
# ('WRC: World Rally Championship', 'Racing', 2002)
# ('Baseball Advance', 'Sports', 2002)
# ('NBA 2K2', 'Sports', 2002)
# ('Virtua Fighter 4', 'Fighting', 2002)
# ('Heroes of Might and Magic IV', 'Strategy', 2002)
# ('Star Trek: Voyager: Elite Force', 'Shooter', 2002)
# ("Tony Hawk's Pro Skater 3", 'Sports', 2002)
# ('Dungeon Siege', 'Action, RPG', 2002)
# ('Baseball Mogul 2003', 'Sports, Simulation', 2002)
# ('Soldier of Fortune II: Double Helix', 'Shooter', 2002)
# ('Hunter: The Reckoning', 'Action', 2002)
# ('MotoGP: Ultimate Racing Technology', 'Racing', 2002)
# ('World Series Baseball [2002]', 'Sports', 2002)
# ('2002 FIFA World Cup', 'Sports', 2002)
# ('The Elder Scrolls III: Morrowind', 'RPG', 2002)
# ('Tactics Ogre: The Knight of Lodis', 'Strategy', 2002)
# ('Resident Evil [2002]', 'Action, Adventure', 2002)
# ('Aggressive Inline', 'Sports', 2002)
# ('The Sum of All Fears', 'Shooter', 2002)
# ('Grand Theft Auto III', 'Action, Adventure', 2002)
# ('Spider-Man: The Movie', 'Action', 2002)
# ('Dance Dance Revolution Konamix', 'Music', 2002)
# ('Arc the Lad Collection', 'RPG', 2002)
# ('Spider-Man: The Movie', 'Action', 2002)
# ('Spider-Man: The Movie', 'Action', 2002)
# ('The Elder Scrolls III: Morrowind', 'RPG', 2002)
# ('Quake II', 'Shooter', 2002)
# ('Quake III: Arena', 'Shooter', 2002)
# ('Unreal Tournament [1999]', 'Shooter', 2002)
# ('Risk II', 'Strategy', 2002)
# ('Majesty: The Fantasy Kingdom', 'Strategy', 2002)
# ('Shadow of Destiny', 'Adventure', 2002)
# ("Sid Meier's Civilization III", 'Strategy', 2002)
# ('Falcon 4.0', 'Flight', 2002)
# ('Caesar III', 'Simulation', 2002)
# ('Deus Ex', 'Shooter', 2002)
# ('Diablo II', 'Action, RPG', 2002)
# ("Age of Wonders II: The Wizard's Throne", 'Strategy', 2002)
# ('Neverwinter Nights', 'RPG', 2002)
# ("Eternal Darkness: Sanity's Requiem", 'Adventure', 2002)
# ('Descent 3', 'Shooter', 2002)
# ('Stuntman', 'Racing, Action', 2002)
# ('WipEout Fusion', 'Racing, Action', 2002)
# ('Medal of Honor: Allied Assault', 'Shooter', 2002)
# ('Warcraft III: Reign of Chaos', 'Strategy', 2002)
# ('Romance of the Three Kingdoms VII', 'Strategy', 2002)
# ('Animal Crossing', 'Simulation', 2002)
# ('Icewind Dale II', 'RPG', 2002)
# ('SEGA GT 2002', 'Racing', 2002)
# ('Mafia', 'Action, Adventure', 2002)
# ("Onimusha 2: Samurai's Destiny", 'Action, Adventure', 2002)
# ('Medieval: Total War', 'Strategy', 2002)
# ('Super Monkey Ball 2', 'Puzzle, Action', 2002)
# ('Madden NFL 2003', 'Sports', 2002)
# ('Super Mario Sunshine', 'Platformer', 2002)
# ("Mat Hoffman's Pro BMX 2", 'Sports', 2002)
# ('Dead to Rights', 'Action', 2002)
# ('SEGA Sports Tennis', 'Sports', 2002)
# ('Beach Spikers', 'Sports', 2002)
# ('Duke Nukem Advance', 'Shooter', 2002)
# ("Clive Barker's Undying", 'Action', 2002)
# ('Aggressive Inline', 'Sports', 2002)
# ('The Mark of Kri', 'Action', 2002)
# ('NCAA Football 2003', 'Sports', 2002)
# ('NCAA Football 2003', 'Sports', 2002)
# ('NFL 2K3', 'Sports', 2002)
# ('Stronghold', 'Strategy', 2002)
# ('NFL 2K3', 'Sports', 2002)
# ('NFL 2K3', 'Sports', 2002)
# ('NCAA Football 2003', 'Sports', 2002)
# ('Warcraft III: Reign of Chaos', 'Strategy', 2002)
# ('Madden NFL 2003', 'Sports', 2002)
# ('Madden NFL 2003', 'Sports', 2002)
# ('Madden NFL 2003', 'Sports', 2002)
# ('Aggressive Inline', 'Sports', 2002)
# ('Fallout 2', 'RPG', 2002)
# ('NASCAR Thunder 2003', 'Racing', 2002)
# ("Kelly Slater's Pro Surfer", 'Sports', 2002)
# ("Kelly Slater's Pro Surfer", 'Sports', 2002)
# ('Tekken 4', 'Fighting', 2002)
# ("Super Mario Advance 3: Yoshi's Island", 'Platformer', 2002)
# ('Burnout 2: Point of Impact', 'Racing', 2002)
# ('Star Fox Adventures', 'Adventure', 2002)
# ('Mega Man Zero', 'Action', 2002)
# ('Soldier of Fortune II: Double Helix', 'Shooter', 2002)
# ('Kingdom Hearts', 'Action, RPG', 2002)
# ('Battlefield 1942', 'Shooter', 2002)
# ('Castlevania: Harmony of Dissonance', 'Action, Adventure', 2002)
# ('NASCAR Thunder 2003', 'Racing', 2002)
# ('Sly Cooper and the Thievius Raccoonus', 'Platformer', 2002)
# ('NASCAR Thunder 2003', 'Racing', 2002)
# ("America's Army", 'Shooter', 2002)
# ("No One Lives Forever 2: A Spy in H.A.R.M.'s Way", 'Shooter', 2002)
# ('Unreal Tournament 2003', 'Shooter', 2002)
# ('Blinx: The Time Sweeper', 'Platformer', 2002)
# ("Super Ghouls 'N Ghosts", 'Action', 2002)
# ('Suikoden III', 'RPG', 2002)
# ('Virtua Tennis', 'Sports', 2002)
# ('Deathrow: Underground Team Combat', 'Sports, Action', 2002)
# ("Baldur's Gate: Dark Alliance", 'Action, RPG', 2002)
# ('DDRMAX: Dance Dance Revolution', 'Music', 2002)
# ('TimeSplitters 2', 'Shooter', 2002)
# ('Hitman 2: Silent Assassin', 'Action', 2002)
# ('NBA Live 2003', 'Sports', 2002)
# ('NBA 2K3', 'Sports', 2002)
# ('Earth & Beyond', 'RPG', 2002)
# ('TimeSplitters 2', 'Shooter', 2002)
# ('TimeSplitters 2', 'Shooter', 2002)
# ('NBA 2K3', 'Sports', 2002)
# ('NBA 2K3', 'Sports', 2002)
# ('Need for Speed: Hot Pursuit 2', 'Racing', 2002)
# ('NHL 2003', 'Sports', 2002)
# ('Spyro the Dragon: Season of Flame', 'Action', 2002)
# ('NHL 2003', 'Sports', 2002)
# ('NHL 2003', 'Sports', 2002)
# ('NHL 2003', 'Sports', 2002)
# ('Red Faction II', 'Shooter', 2002)
# ('NBA Live 2003', 'Sports', 2002)
# ('NBA Live 2003', 'Sports', 2002)
# ('Hitman 2: Silent Assassin', 'Action', 2002)
# ('Ratchet & Clank [2002]', 'Platformer', 2002)
# ('Age of Mythology', 'Strategy', 2002)
# ('Phantasy Star Online Episode I & II', 'RPG', 2002)
# ('Divine Divinity', 'RPG', 2002)
# ('Shenmue II', 'Action, RPG', 2002)
# ("Tony Hawk's Pro Skater 4", 'Sports', 2002)
# ('Tiger Woods PGA Tour 2003', 'Sports', 2002)
# ('Grand Theft Auto: Vice City', 'Action, Adventure', 2002)
# ("Tony Hawk's Pro Skater 4", 'Sports', 2002)
# ('Tiger Woods PGA Tour 2003', 'Sports', 2002)
# ('Tiger Woods PGA Tour 2003', 'Sports', 2002)
# ("Tony Hawk's Pro Skater 4", 'Sports', 2002)
# ('Colin McRae Rally 2.0', 'Racing', 2002)
# ("Tony Hawk's Pro Skater 4", 'Sports', 2002)
# ('Dr. Muto', 'Platformer', 2002)
# ('Metroid Prime', 'Action, Adventure', 2002)
# ('NHL 2K3', 'Sports', 2002)
# ('MechWarrior 4: Mercenaries', 'Action, Simulation', 2002)
# ('Metal Gear Solid 2: Substance', 'Action, Adventure', 2002)
# ('Harry Potter and the Chamber of Secrets', 'Action, Adventure', 2002)
# ('The Sims (Deluxe Edition)', 'Simulation', 2002)
# ('Harry Potter and the Chamber of Secrets', 'Action, Adventure', 2002)
# ('Metroid Fusion', 'Action, Adventure', 2002)
# ('Tiger Woods PGA Tour 2003', 'Sports', 2002)
# ('MechAssault', 'Action', 2002)
# ('V-Rally 3', 'Racing', 2002)
# ('ATV Offroad Fury 2', 'Racing', 2002)
# ('Rocky', 'Sports', 2002)
# ('NHL 2K3', 'Sports', 2002)
# ('NHL 2K3', 'Sports', 2002)
# ('Rocky', 'Fighting', 2002)
# ('Unreal Championship', 'Shooter', 2002)
# ('Dr. Muto', 'Platformer', 2002)
# ('Dr. Muto', 'Platformer', 2002)
# ('Star Wars Jedi Knight II: Jedi Outcast', 'Action', 2002)
# ('Mortal Kombat: Deadly Alliance', 'Fighting', 2002)
# ('Combat Mission: Barbarossa to Berlin', 'Strategy', 2002)
# ('James Bond 007: NightFire', 'Shooter', 2002)
# ("Tom Clancy's Splinter Cell", 'Adventure', 2002)
# ("Tom Clancy's Ghost Recon", 'Shooter', 2002)
# ('Activision Anthology', 'Compilation', 2002)
# ('No One Lives Forever', 'Shooter', 2002)
# ('Mortal Kombat: Deadly Alliance', 'Fighting', 2002)
# ('Mortal Kombat: Deadly Alliance', 'Fighting', 2002)
# ('Mortal Kombat: Deadly Alliance', 'Fighting', 2002)
# ('Emperor: Rise of the Middle Kingdom', 'Simulation', 2002)
# ('The Thing', 'Action, Adventure', 2002)
# ('Europa 1400: The Guild', 'Simulation', 2002)
# ('NCAA College Basketball 2K3', 'Sports', 2002)
# ('NCAA College Basketball 2K3', 'Sports', 2002)
# ('NCAA College Basketball 2K3', 'Sports', 2002)
# ('NBA Live 2003', 'Sports', 2002)
# ('Star Wars Jedi Knight II: Jedi Outcast', 'Action', 2002)
# ('The Legend of Zelda: A Link to the Past w/ the Four Swords', 'Action, Adventure', 2002)
# ('Kirby: Nightmare in Dream Land', 'Platformer', 2002)
# ('Super Monkey Ball Jr.', 'Puzzle, Action', 2002)
# ('Street Fighter Alpha 3', 'Fighting', 2002)
# ("Asheron's Call 2", 'RPG', 2002)
# ('Hearts of Iron', 'Strategy', 2002)
# ('Pro Race Driver', 'Racing', 2002)
# ('The Elder Scrolls III: Tribunal', 'RPG', 2002)
# ('GT Advance 3: Pro Concept Racing', 'Racing', 2003)
# ('Guilty Gear X2', 'Fighting', 2003)
# ('FIFA Soccer 2003', 'Sports', 2003)
# ('Battlefield 1942: The Road to Rome', 'Shooter', 2003)
# ('Crimson Sea', 'RPG', 2003)
# ('War of the Monsters', 'Fighting', 2003)
# ('Heroes of Might and Magic IV', 'Strategy', 2003)
# ('Skies of Arcadia Legends', 'RPG', 2003)
# ('Dark Age of Camelot: Shrouded Isles', 'RPG', 2002)
# ('Dead or Alive Xtreme Beach Volleyball', 'Sports', 2003)
# ('Anarchy Online: The Notum Wars', 'RPG', 2002)
# ('Crash Bandicoot 2: N-tranced', 'Platformer', 2003)
# ('Karnaaj Rally', 'Racing', 2003)
# ('Dr. Muto', 'Platformer', 2003)
# ('Dark Cloud 2', 'Action, RPG', 2003)
# ('SimCity 4', 'Simulation', 2003)
# ('Moto Racer Advance', 'Racing', 2003)
# ('Panzer Dragoon Orta', 'Shooter', 2003)
# ('.hack//INFECTION (Part 1)', 'Action, RPG', 2003)
# ('Command & Conquer Generals', 'Strategy', 2003)
# ('Capcom vs. SNK 2 EO', 'Fighting', 2003)
# ('Rayman 3', 'Platformer', 2003)
# ('Tenchu: Wrath of Heaven', 'Action', 2003)
# ('Metal Gear Solid 2: Substance', 'Action, Adventure', 2003)
# ('Colin McRae Rally 3', 'Racing', 2003)
# ('The Legend of Zelda: Ocarina of Time / Master Quest', 'Action, Adventure', 2003)
# ('Freelancer', 'Action, Simulation', 2003)
# ('Xenosaga Episode I: Der Wille zur Macht', 'RPG', 2003)
# ("Tom Clancy's Splinter Cell", 'Adventure', 2003)
# ('Master of Orion III', 'Strategy', 2003)
# ('The Sims', 'Simulation', 2003)
# ("Tom Clancy's Splinter Cell", 'Action, Adventure', 2003)
# ('Amplitude [2003]', 'Music, Action', 2003)
# ('Dynasty Warriors 4', 'Action', 2003)
# ('The Legend of Zelda: The Wind Waker', 'Action, Adventure', 2003)
# ('Winning Eleven 6 Final Evolution', 'Sports', 2003)
# ("Tom Clancy's Rainbow Six 3: Raven Shield", 'Shooter', 2003)
# ('Pokemon Sapphire Version', 'RPG', 2003)
# ('Tao Feng: Fist of the Lotus', 'Fighting', 2003)
# ('Sonic Advance 2', 'Platformer', 2003)
# ('Ultimate Brain Games', 'Puzzle', 2003)
# ('Rayman 3: Hoodlum Havoc', 'Action', 2003)
# ('Black & White (Platinum Pack)', 'Compilation', 2003)
# ('Praetorians', 'Strategy', 2003)
# ('Delta Force: Black Hawk Down', 'Shooter', 2003)
# ('Rayman 3: Hoodlum Havoc', 'Platformer', 2003)
# ('MotoGP 3', 'Racing', 2003)
# ('Pokemon Ruby Version', 'RPG', 2003)
# ('NASCAR Racing: 2003 Season', 'Racing', 2003)
# ('A Tale in the Desert', 'RPG', 2003)
# ('MVP Baseball 2003', 'Sports', 2003)
# ('MVP Baseball 2003', 'Sports', 2003)
# ('Zone of the Enders: The 2nd Runner', 'Action', 2003)
# ('World Series Baseball 2K3', 'Sports', 2003)
# ('Def Jam Vendetta', 'Wrestling', 2003)
# ('World Soccer Winning Eleven 6 International', 'Sports', 2003)
# ('World Series Baseball 2K3', 'Sports', 2003)
# ('Def Jam Vendetta', 'Wrestling', 2003)
# ('IL-2 Sturmovik: Forgotten Battles -- WWII 1941-1944', 'Flight, Simulation', 2003)
# ('Grand Prix Challenge', 'Racing', 2003)
# ('Mega Man & Bass', 'Action', 2003)
# ('Rayman 3: Hoodlum Havoc', 'Action', 2003)
# ('The Sims', 'Simulation', 2003)
# ('Pro Race Driver', 'Racing', 2003)
# ('The Sims', 'Simulation', 2003)
# ('Final Fantasy Origins', 'RPG', 2003)
# ('Godzilla: Destroy All Monsters Melee', 'Fighting, Action', 2003)
# ("Tom Clancy's Splinter Cell", 'Action', 2003)
# ('Ikaruga', 'Shooter', 2003)
# ('Midnight Club II', 'Racing', 2003)
# ('Burnout 2: Point of Impact', 'Racing', 2003)
# ('Metal Gear Solid 2: Substance', 'Action, Adventure', 2003)
# ('The Lost Vikings', 'Puzzle', 2003)
# ('Red Faction II', 'Shooter', 2003)
# ('Pitfall', 'Platformer', 2003)
# ("EverQuest for Pocket PC: Hero's Call", 'RPG', 2003)
# ('Prince of Persia: Harem Adventures', 'Action, Adventure', 2003)
# ('Return to Castle Wolfenstein: Tides of War', 'Shooter', 2003)
# ('Gundam: Space Assault', 'Shooter', 2003)
# ('NBA Street Vol. 2', 'Sports', 2003)
# ('NBA Street Vol. 2', 'Sports', 2003)
# ('Castlevania: Aria of Sorrow', 'Action, Adventure', 2003)
# ("Burnout 2: Point of Impact -- Developer's Cut", 'Racing', 2003)
# ('Baku Baku', 'Puzzle', 2003)
# ('NBA Street Vol. 2', 'Sports', 2003)
# ('Ninja Five-O', 'Action', 2003)
# ('Colin McRae Rally 3', 'Racing', 2003)
# ('Siberian Strike', 'Shooter', 2003)
# ('Rayman 3', 'Platformer', 2003)
# ('Wario Ware, Inc: Mega Microgame$', 'Party', 2003)
# ('Grand Theft Auto: Vice City', 'Action, Adventure', 2003)
# ('Lemonade Tycoon', 'Simulation', 2003)
# ("Tom Clancy's Splinter Cell", 'Action', 2003)
# ('Midtown Madness 3', 'Racing', 2003)
# ('Moon Patrol', 'Action', 2003)
# ('Midnight Club II', 'Racing', 2003)
# ('Wakeboarding Unleashed Featuring Shaun Murray', 'Sports', 2003)
# ('Wakeboarding Unleashed Featuring Shaun Murray', 'Sports', 2003)
# ('Chessmaster', 'Board', 2003)
# ('The Elder Scrolls III: Bloodmoon', 'RPG', 2003)
# ('Port Royale', 'Strategy', 2003)
# ("Rock 'n Roll Racing", 'Racing', 2003)
# ('Medieval: Total War -- Viking Invasion', 'Strategy', 2003)
# ('Return to Castle Wolfenstein: Enemy Territory', 'Shooter', 2003)
# ('MotoGP 2', 'Racing', 2003)
# ('Magic Pengel: The Quest for Color', 'Battle', 2003)
# ('Age of Wonders: Shadow Magic', 'Strategy', 2003)
# ('Microsoft Flight Simulator 2004: A Century of Flight', 'Flight, Simulation', 2003)
# ('Combat Mission: Beyond Overlord (Special Edition)', 'Strategy', 2003)
# ('IndyCar Series', 'Racing', 2003)
# ('FOX Sports On-Field Live Football', 'Sports', 2003)
# ('Star Wars Knights of the Old Republic', 'RPG', 2003)
# ("F1 Challenge '99-'02", 'Racing, Simulation', 2003)
# ('FOX Sports Boxing', 'Sports', 2003)
# ('Advance Wars 2: Black Hole Rising', 'Strategy', 2003)
# ('Jet Grind Radio', 'Action', 2003)
# ('FOX Sports On-Court Live Basketball', 'Sports, Action', 2003)
# ('Midnight Club II', 'Racing', 2003)
# ('NCAA Football 2004', 'Sports', 2003)
# ('NCAA Football 2004', 'Sports', 2003)
# ('NCAA Football 2004', 'Sports', 2003)
# ("Tony Hawk's Pro Skater 4", 'Sports, Action', 2003)
# ('Otogi: Myth of Demons', 'Action', 2003)
# ('F-Zero GX', 'Racing', 2003)
# ('Virtua Fighter 4: Evolution', 'Fighting', 2003)
# ('Ape Escape 2', 'Platformer', 2003)
# ('Warcraft III: The Frozen Throne', 'Strategy', 2003)
# ('Pokemon Pinball: Ruby & Sapphire', 'Pinball', 2003)
# ('Dance Nation: Ministry of Sound', 'Music', 2003)
# ('Legacy Online', 'Strategy', 2003)
# ('Madden NFL 2004', 'Sports', 2003)
# ('Silent Hill 3', 'Adventure', 2003)
# ('River Raid', 'Shooter', 2003)
# ('Splashdown: Rides Gone Wild', 'Racing, Action', 2003)
# ('Stuntman', 'Racing, Action', 2003)
# ('Madden NFL 2004', 'Sports', 2003)
# ('Madden NFL 2004', 'Sports', 2003)
# ('Madden NFL 2004', 'Sports', 2003)
# ('Romance of the Three Kingdoms VIII', 'Strategy', 2003)
# ('ESPN NFL Football', 'Sports', 2003)
# ('RotoSphere', 'Puzzle', 2003)
# ('MLB Slam!', 'Sports', 2003)
# ("Tony Hawk's Pro Skater 4", 'Sports', 2003)
# ('Mortal Kombat: Tournament Edition', 'Fighting', 2003)
# ('Soulcalibur II', 'Fighting', 2003)
# ('Disgaea: Hour of Darkness', 'Strategy, RPG', 2003)
# ('Bombastic', 'Puzzle', 2003)
# ('Soulcalibur II', 'Fighting', 2003)
# ('Soulcalibur II', 'Fighting', 2003)
# ('EverQuest: Lost Dungeons of Norrath', 'RPG', 2003)
# ('NHL Hitz: Pro', 'Sports, Action', 2003)
# ('NHL 2004', 'Sports', 2003)
# ('Command & Conquer Generals Zero Hour', 'Strategy', 2003)
# ('NHL Hitz Pro', 'Sports, Action', 2003)
# ('NHL Hitz Pro', 'Sports, Action', 2003)
# ('Boktai', 'Action, Adventure', 2003)
# ('Star Wars Jedi Knight: Jedi Academy', 'Shooter', 2003)
# ('Savage: The Battle for Newerth', 'Strategy', 2003)
# ('NHL 2004', 'Sports', 2003)
# ('NHL 2004', 'Sports', 2003)
# ('NASCAR Thunder 2004', 'Racing', 2003)
# ('Tiger Woods PGA Tour 2004', 'Sports', 2003)
# ('Freedom Fighters', 'Action, Adventure', 2003)
# ('Freedom Fighters', 'Action, Adventure', 2003)
# ('Super Mario Advance 4: Super Mario Bros. 3', 'Platformer', 2003)
# ('NBA Live 2004', 'Sports', 2003)
# ('Dynasty Warriors 4', 'Action', 2003)
# ('Battlefield 1942: Secret Weapons of World War II', 'Shooter', 2003)
# ('ESPN NHL Hockey', 'Sports', 2003)
# ('Tiger Woods PGA Tour 2004', 'Sports', 2003)
# ('NASCAR Thunder 2004', 'Racing', 2003)
# ('Tiger Woods PGA Tour 2004', 'Sports', 2003)
# ('Tiger Woods PGA Tour 2004', 'Sports', 2003)
# ('Freedom Fighters', 'Action, Adventure', 2003)
# ("FOX Sports Football '04", 'Sports', 2003)
# ('Viewtiful Joe', 'Fighting, Action', 2003)
# ('JAMDAT Racing', 'Racing', 2003)
# ('ESPN NHL Hockey', 'Sports', 2003)
# ('Anarchy Online: Shadowlands', 'RPG', 2003)
# ('Homeworld 2', 'Strategy', 2003)
# ('WWE Raw 2', 'Wrestling', 2003)
# ('Freedom Fighters', 'Action, Adventure', 2003)
# ('Age of Mythology: The Titans', 'Strategy', 2003)
# ('Jak II', 'Platformer', 2003)
# ('Hoyle Majestic Chess', 'Board', 2003)
# ('Final Fantasy Tactics Advance', 'Strategy, RPG', 2003)
# ('ESPN NFL Football', 'Sports', 2003)
# ('NHL 2004', 'Sports', 2003)
# ('DDRMAX2: Dance Dance Revolution', 'Music', 2003)
# ('Crimson Skies: High Road to Revenge', 'Flight, Action', 2003)
# ('Castlevania: Lament of Innocence', 'Action, Adventure', 2003)
# ('Warlords IV: Heroes of Etheria', 'Strategy', 2003)
# ("Tony Hawk's Underground", 'Sports', 2003)
# ('Call of Duty', 'Shooter', 2003)
# ('SSX 3', 'Sports', 2003)
# ('SSX 3', 'Sports', 2003)
# ('SSX 3', 'Sports', 2003)
# ('WWE SmackDown! Here Comes the Pain', 'Wrestling', 2003)
# ('Empires: Dawn of the Modern World', 'Strategy', 2003)
# ('Grand Theft Auto Double Pack: Grand Theft Auto III & Grand Theft Auto: Vice City', 'Action, Adventure', 2003)
# ('Max Payne 2: The Fall of Max Payne', 'Shooter', 2003)
# ("Tony Hawk's Pro Skater", 'Sports', 2003)
# ('Patrician III', 'Simulation', 2003)
# ('Commandos 3: Destination Berlin', 'Strategy', 2003)
# ('ESPN NBA Basketball', 'Sports', 2003)
# ('ESPN NBA Basketball', 'Sports', 2003)
# ("Tom Clancy's Rainbow Six 3", 'Shooter', 2003)
# ("Tony Hawk's Underground", 'Sports', 2003)
# ('Amped 2', 'Sports', 2003)
# ('Top Spin', 'Sports', 2003)
# ("Tony Hawk's Underground", 'Sports', 2003)
# ("Tony Hawk's Underground", 'Sports', 2003)
# ('The Lord of the Rings: The Return of the King', 'Action', 2003)
# ('The Lord of the Rings: The Return of the King', 'Action', 2003)
# ('The Lord of the Rings: The Return of the King', 'Action', 2003)
# ('The Lord of the Rings: The Return of the King', 'Action', 2003)
# ("Sid Meier's Civilization III: Conquests", 'Strategy', 2003)
# ('True Crime: Streets of L.A.', 'Action, Adventure', 2003)
# ('True Crime: Streets of L.A.', 'Action, Adventure', 2003)
# ('True Crime: Streets of L.A.', 'Action, Adventure', 2003)
# ('Need for Speed Underground', 'Racing', 2003)
# ('ESPN College Hoops', 'Sports', 2003)
# ('FIFA Soccer 2004', 'Sports', 2003)
# ('Need for Speed Underground', 'Racing', 2003)
# ('FIFA Soccer 2004', 'Sports', 2003)
# ('FIFA Soccer 2004', 'Sports', 2003)
# ('Prince of Persia: The Sands of Time', 'Action, Adventure', 2003)
# ('Final Fantasy X-2', 'RPG', 2003)
# ('Railroad Tycoon 3', 'Simulation', 2003)
# ('Fire Emblem', 'Strategy, RPG', 2003)
# ('Karaoke Revolution [2004]', 'Music', 2003)
# ('Grand Theft Auto Double Pack: Grand Theft Auto III & Grand Theft Auto: Vice City', 'Action, Adventure', 2003)
# ('SOCOM II: U.S. Navy SEALs', 'Shooter', 2003)
# ('Beyond Good & Evil', 'Action, Adventure', 2003)
# ('Manhunt', 'Action', 2003)
# ('Beyond Good & Evil', 'Action, Adventure', 2003)
# ('Beyond Good & Evil', 'Action, Adventure', 2003)
# ('Beyond Good & Evil', 'Action, Adventure', 2003)
# ('Ratchet & Clank: Going Commando', 'Platformer', 2003)
# ('Rayman Bowling', 'Sports, Action', 2003)
# ('Prince of Persia: The Sands of Time', 'Action, Adventure', 2003)
# ('Project Gotham Racing 2', 'Racing', 2003)
# ('Prince of Persia: The Sands of Time', 'Action, Adventure', 2003)
# ('Mario & Luigi: Superstar Saga', 'RPG', 2003)
# ('Need for Speed Underground', 'Racing', 2003)
# ...
# ('Might and Magic: Clash of Heroes', 'Puzzle, Adventure', 2013)
# ('Antichamber', 'Puzzle', 2013)
# ('Antichamber', 'Puzzle', 2013)
# ('Fatal Frame: Deep Crimson Butterfly', 'Adventure', 2012)
# ('Pixel People', 'Simulation', 2013)
# ('Fire Emblem Awakening', 'Strategy, RPG', 2013)
# ('Theatrhythm Final Fantasy', 'Music, Action', 2012)
# ('The Walking Dead: The Game -- Episode 2: Starved For Help', 'Adventure', 2012)
# ('Tomb Raider', 'Action', 2013)
# ('Bit.Trip Presents: Runner 2 Future Legend of Rhythm Alien', 'Platformer', 2013)
# ('Bit.Trip Presents: Runner 2 Future Legend of Rhythm Alien', 'Platformer', 2013)
# ('Tomb Raider', 'Action', 2013)
# ('HarmoKnight', 'Platformer', 2013)
# ('Need for Speed Most Wanted U', 'Racing, Action', 2013)
# ("Luigi's Mansion: Dark Moon", 'Platformer', 2013)
# ('BioShock Infinite', 'Shooter', 2013)
# ('BioShock Infinite', 'Shooter', 2013)
# ('BioShock Infinite', 'Shooter', 2013)
# ('Real Racing 3', 'Racing', 2013)
# ('Bit.Trip Presents: Runner 2 Future Legend of Rhythm Alien', 'Platformer', 2013)
# ('Bit.Trip Presents: Runner 2 Future Legend of Rhythm Alien', 'Platformer', 2013)
# ('Tomb Raider', 'Action', 2013)
# ('Bit.Trip Presents: Runner 2 Future Legend of Rhythm Alien', 'Platformer', 2013)
# ('Guacamelee!', 'Platformer, Action', 2013)
# ('Guacamelee!', 'Platformer, Action', 2013)
# ('Terraria', 'Action, RPG', 2013)
# ('Terraria', 'Action, RPG', 2013)
# ('Incredipede', 'Puzzle, Adventure', 2013)
# ('Incredipede', 'Puzzle, Adventure', 2013)
# ('The Swapper', 'Platformer', 2013)
# ('The Swapper', 'Platformer', 2013)
# ('The Swapper', 'Platformer', 2013)
# ('Fez', 'Platformer', 2013)
# ('Fez', 'Platformer', 2013)
# ('Monaco', 'Action', 2013)
# ('Monaco', 'Action', 2013)
# ('Donkey Kong Country Returns 3D', 'Platformer', 2013)
# ('Star Wars: The Old Republic', 'RPG', 2013)
# ('Fez', 'Platformer', 2013)
# ('Fez', 'Platformer', 2013)
# ('Limbo', 'Platformer', 2013)
# ('Kentucky Route Zero: Act 2', 'Adventure', 2013)
# ('Kentucky Route Zero: Act 2', 'Adventure', 2013)
# ('Kentucky Route Zero: Act 2', 'Adventure', 2013)
# ("Sid Meier's Civilization V: Brave New World", 'Strategy', 2013)
# ("Sid Meier's Civilization V: Brave New World", 'Strategy', 2013)
# ("Borderlands 2: Tiny Tina's Assault on Dragon Keep", 'Shooter, RPG', 2013)
# ('Rogue Legacy', 'RPG', 2013)
# ('Gunpoint', 'Puzzle, Action', 2013)
# ('Rogue Legacy', 'RPG', 2013)
# ('Rogue Legacy', 'RPG', 2013)
# ('Rogue Legacy', 'RPG', 2013)
# ('The Last of Us', 'Action', 2013)
# ('Animal Crossing: New Leaf', 'Simulation', 2013)
# ('Gone Home', 'Simulation', 2013)
# ('Gone Home', 'Simulation', 2013)
# ('Gone Home', 'Simulation', 2013)
# ('Gone Home', 'Simulation', 2013)
# ('Gone Home', 'Simulation', 2013)
# ("Tom Clancy's Splinter Cell: Blacklist", 'Action', 2013)
# ("Tom Clancy's Splinter Cell: Blacklist", 'Action', 2013)
# ('Dota 2', 'RPG', 2013)
# ('Pikmin 3', 'Strategy', 2013)
# ('The Swapper', 'Platformer', 2013)
# ('The Legend of Zelda: The Wind Waker HD', 'Action, Adventure', 2013)
# ('The Legend of Zelda: The Wind Waker HD (Nintendo eShop Edition)', 'Action, Adventure', 2013)
# ('Grand Theft Auto V', 'Action, Adventure', 2013)
# ('Grand Theft Auto V', 'Action, Adventure', 2013)
# ("Tom Clancy's Splinter Cell: Blacklist", 'Action', 2013)
# ("Tom Clancy's Splinter Cell: Blacklist", 'Action', 2013)
# ('Rayman Legends', 'Platformer', 2013)
# ('Rayman Legends', 'Platformer', 2013)
# ('Rayman Legends', 'Platformer', 2013)
# ('Rayman Legends', 'Platformer', 2013)
# ('Rayman Legends', 'Platformer', 2013)
# ('Diablo III', 'Action, RPG', 2013)
# ('Diablo III', 'Action, RPG', 2013)
# ('Total War: Rome II', 'Strategy', 2013)
# ('Rayman Legends', 'Platformer', 2013)
# ('Spelunky', 'Platformer', 2013)
# ('The Raven: Legacy of a Master Thief Chapter I: The Eye of the Sphinx', 'Adventure', 2013)
# ('The Raven: Legacy of a Master Thief Chapter I: The Eye of the Sphinx', 'Adventure', 2013)
# ('The Raven: Legacy of a Master Thief Chapter I: The Eye of the Sphinx', 'Adventure', 2013)
# ('The Raven: Legacy of a Master Thief Chapter I: The Eye of the Sphinx', 'Adventure', 2013)
# ('The Raven: Legacy of a Master Thief Chapter I: The Eye of the Sphinx', 'Adventure', 2013)
# ('The Wolf Among Us: Episode 1 -- Faith', 'Adventure', 2013)
# ('The Wolf Among Us: Episode 1 -- Faith', 'Adventure', 2013)
# ('The Wolf Among Us: Episode 1 -- Faith', 'Adventure', 2013)
# ('The Wolf Among Us: Episode 1 -- Faith', 'Adventure', 2013)
# ('Disgaea D2: A Brighter Darkness', 'Action', 2013)
# ('Pokemon Y', 'RPG', 2013)
# ('Pokemon X', 'RPG', 2013)
# ('NBA 2K14', 'Sports', 2013)
# ('NBA 2K14', 'Sports', 2013)
# ('Scribblenauts Unmasked: A DC Comics Adventure', 'Puzzle, Action', 2013)
# ('Scribblenauts Unmasked: A DC Comics Adventure', 'Puzzle, Action', 2013)
# ('Scribblenauts Unmasked: A DC Comics Adventure', 'Puzzle, Action', 2013)
# ('FIFA 14', 'Sports', 2013)
# ('FIFA 14', 'Sports', 2013)
# ('LEGO Marvel Super Heroes', 'Action', 2013)
# ('LEGO Marvel Super Heroes', 'Action', 2013)
# ('LEGO Marvel Super Heroes', 'Action', 2013)
# ('LEGO Marvel Super Heroes', 'Action', 2013)
# ('LEGO Marvel Super Heroes', 'Action', 2013)
# ('LEGO Marvel Super Heroes', 'Action', 2013)
# ('XCOM: Enemy Within', 'Strategy', 2013)
# ('XCOM: Enemy Within -- Commander Edition', 'Strategy', 2013)
# ('Infinity Blade III', 'Fighting, Action', 2013)
# ('SteamWorld Dig', 'Platformer', 2013)
# ('SteamWorld Dig', 'Platformer', 2013)
# ('SteamWorld Dig', 'Platformer', 2013)
# ('SteamWorld Dig', 'Platformer', 2013)
# ('The Pinball Arcade', 'Pinball', 2013)
# ('The Legend of Zelda: A Link Between Worlds', 'Adventure', 2013)
# ('Resogun', 'Shooter', 2013)
# ('Flower', 'Action', 2013)
# ('Marvel Puzzle Quest: Dark Reign', 'Puzzle, RPG', 2013)
# ('Professor Layton and the Azran Legacy', 'Adventure', 2013)
# ('XCOM: Enemy Within -- Commander Edition', 'Strategy', 2013)
# ('Forza Motorsport 5', 'Racing', 2013)
# ('Tearaway', 'Adventure', 2013)
# ('Super Mario 3D World', 'Platformer', 2013)
# ('The Pinball Arcade', 'Pinball', 2013)
# ('Rocksmith 2014', 'Music', 2013)
# ('Rocksmith 2014', 'Music', 2013)
# ('Rocksmith 2014', 'Music', 2013)
# ('Rocksmith 2014', 'Music', 2013)
# ('Flower', 'Action', 2013)
# ('FIFA 14', 'Sports', 2013)
# ('FIFA 14', 'Sports', 2013)
# ('FIFA 14', 'Sports', 2013)
# ('Device 6', 'Puzzle, Adventure', 2013)
# ('Tomb Raider: Definitive Edition', 'Action', 2014)
# ('Tomb Raider: Definitive Edition', 'Action', 2014)
# ('Minecraft', 'Action', 2014)
# ('Minecraft', 'Action', 2014)
# ('Broken Age: Act 1', 'Adventure', 2014)
# ('Broken Age: Act 1', 'Adventure', 2014)
# ('Nidhogg', 'Fighting', 2014)
# ('Terraria', 'Action, RPG', 2013)
# ('Peggle 2', 'Puzzle, Action', 2013)
# ('Peggle 2', 'Puzzle, Action', 2013)
# ('The Last of Us: Left Behind', 'Action, Adventure', 2014)
# ('League of Legends', 'Action', 2014)
# ('League of Legends', 'Action', 2014)
# ('Titanfall', 'Shooter, First-Person', 2014)
# ('Final Fantasy X / X-2 HD Remaster', 'RPG', 2014)
# ('Final Fantasy X / X-2 HD Remaster (Limited Edition)', 'RPG', 2014)
# ('Final Fantasy X / X-2 HD Remaster', 'RPG', 2014)
# ('The Walking Dead: Season Two -- Episode 2: A House Divided', 'Adventure', 2014)
# ('The Walking Dead: Season Two -- Episode 2: A House Divided', 'Adventure', 2014)
# ('The Walking Dead: Season Two -- Episode 2: A House Divided', 'Adventure', 2014)
# ('The Walking Dead: Season Two -- Episode 2: A House Divided', 'Adventure', 2014)
# ('The Walking Dead: Season Two -- Episode 2: A House Divided', 'Adventure', 2014)
# ('South Park: The Stick of Truth', 'RPG', 2014)
# ('South Park: The Stick of Truth', 'RPG', 2014)
# ('South Park: The Stick of Truth', 'RPG', 2014)
# ('Hearthstone: Heroes of WarCraft', 'Card, Battle', 2014)
# ('Hearthstone: Heroes of WarCraft', 'Card, Battle', 2014)
# ('Hearthstone: Heroes of WarCraft', 'Card, Battle', 2014)
# ('Dark Souls II', 'Action, RPG', 2014)
# ('Dark Souls II', 'Action, RPG', 2014)
# ('Dark Souls II', 'Action, RPG', 2014)
# ('Titanfall', 'Shooter, First-Person', 2014)
# ('Titanfall', 'Shooter, First-Person', 2014)
# ("Titanfall (Collector's Edition)", 'Shooter, First-Person', 2014)
# ('The Wolf Among Us: Episode 3 -- A Crooked Mile', 'Adventure', 2014)
# ('The Wolf Among Us: Episode 3 -- A Crooked Mile', 'Adventure', 2014)
# ('The Wolf Among Us: Episode 3 -- A Crooked Mile', 'Adventure', 2014)
# ('Diablo III: Reaper of Souls', 'Action, RPG', 2014)
# ('Diablo III: Reaper of Souls', 'Action, RPG', 2014)
# ('Child of Light', 'RPG', 2014)
# ('Child of Light', 'RPG', 2014)
# ('Child of Light', 'RPG', 2014)
# ('Child of Light', 'RPG', 2014)
# ('Child of Light', 'RPG', 2014)
# ('Child of Light', 'RPG', 2014)
# ('Child of Light', 'RPG', 2014)
# ('Shovel Knight', 'Platformer, Adventure', 2014)
# ('Shovel Knight', 'Platformer, Adventure', 2014)
# ('Shovel Knight', 'Platformer, Adventure', 2014)
# ('Shovel Knight', 'Platformer, Adventure', 2014)
# ('Shovel Knight', 'Platformer, Adventure', 2014)
# ('Shovel Knight', 'Platformer, Adventure', 2014)
# ('FTL: Faster Than Light', 'Simulation', 2014)
# ('FTL: Faster Than Light', 'Simulation', 2014)
# ('Divinity: Original Sin', 'RPG', 2014)
# ('Ultra Street Fighter IV', 'Fighting', 2014)
# ('Transistor', 'Action, RPG', 2014)
# ('Transistor', 'Action, RPG', 2014)
# ('Mario Kart 8', 'Racing, Action', 2014)
# ("The Walking Dead: Season Two -- Episode 3: In Harm's Way", 'Adventure', 2014)
# ('The Walking Dead: Season Two -- Episode 5: No Going Back', 'Adventure', 2014)
# ('Diablo III: Ultimate Evil Edition', 'Action, RPG', 2014)
# ('Diablo III: Ultimate Evil Edition', 'Action, RPG', 2014)
# ('The Last of Us: Remastered', 'Action', 2014)
# ('Persona 4 Arena Ultimax', 'Fighting', 2014)
# ('Persona 4 Arena Ultimax', 'Fighting', 2014)
# ('Middle-earth: Shadow of Mordor', 'Action, Adventure', 2014)
# ('Middle-earth: Shadow of Mordor', 'Action, Adventure', 2014)
# ('Middle-earth: Shadow of Mordor', 'Action, Adventure', 2014)
# ('Forza Horizon 2', 'Racing', 2014)
# ('Minecraft', 'Action', 2014)
# ('Minecraft', 'Action', 2014)
# ('Velocity 2X', 'Shooter', 2014)
# ('Velocity 2X', 'Shooter', 2014)
# ('The Walking Dead: Season Two -- Episode 5: No Going Back', 'Adventure', 2014)
# ('The Walking Dead: Season Two -- Episode 5: No Going Back', 'Adventure', 2014)
# ('The Walking Dead: Season Two -- Episode 5: No Going Back', 'Adventure', 2014)
# ('The Walking Dead: Season Two -- Episode 5: No Going Back', 'Adventure', 2014)
# ('Bayonetta 2', 'Action', 2014)
# ('Halo: The Master Chief Collection', 'Shooter', 2014)
# ('Call of Duty: Advanced Warfare', 'Shooter', 2014)
# ('Call of Duty: Advanced Warfare', 'Shooter', 2014)
# ('Call of Duty: Advanced Warfare', 'Shooter', 2014)
# ('Call of Duty: Advanced Warfare', 'Shooter', 2014)
# ('Call of Duty: Advanced Warfare', 'Shooter', 2014)
# ('Pro Evolution Soccer 2015', 'Sports', 2014)
# ('Pro Evolution Soccer 2015', 'Sports', 2014)
# ('Pro Evolution Soccer 2015', 'Sports', 2014)
# ('Pro Evolution Soccer 2015', 'Sports', 2014)
# ('Pro Evolution Soccer 2015', 'Sports', 2014)
# ('World of Warcraft: Warlords of Draenor', 'RPG', 2014)
# ('The Binding of Isaac: Rebirth', 'RPG', 2014)
# ('The Binding of Isaac: Rebirth', 'RPG', 2014)
# ('Super Smash Bros. for Wii U', 'Fighting', 2014)
# ('Grand Theft Auto V', 'Action, Adventure', 2014)
# ('Grand Theft Auto V', 'Action, Adventure', 2014)
# ('Threes', 'Puzzle', 2014)
# ('Threes', 'Puzzle', 2014)
# ('Threes', 'Puzzle', 2014)
# ('80 Days', 'Adventure', 2014)
# ('Evolve', 'Shooter', 2015)
# ('Evolve', 'Shooter', 2015)
# ('Evolve', 'Shooter', 2015)
# ('Monster Hunter 4 Ultimate', 'Action', 2015)
# ('Grand Theft Auto V', 'Action, Adventure', 2015)
# ('Grim Fandango Remastered', 'Adventure', 2015)
# ('Grim Fandango Remastered', 'Adventure', 2015)
# ('Grim Fandango Remastered', 'Adventure', 2015)
# ('OlliOlli 2: Welcome to OlliWood', 'Sports', 2015)
# ('OlliOlli 2: Welcome to OlliWood', 'Sports', 2015)
# ('Invisible Inc.', 'Strategy', 2015)
# ('The Witcher 3: Wild Hunt', 'RPG', 2015)
# ('The Witcher 3: Wild Hunt', 'RPG', 2015)
# ('Halo 3: ODST [The Master Chief Collection]', 'Shooter', 2015)
# ('Homeworld Remastered Collection', 'Strategy', 2015)
# ('The Witcher 3: Wild Hunt', 'RPG', 2015)
# ('Final Fantasy X / X-2 HD Remaster', 'RPG', 2015)
# ('Project CARS', 'Racing', 2015)
# ('Pillars of Eternity', 'RPG', 2015)
# ('Helldivers', 'Shooter', 2015)
# ('Helldivers', 'Shooter', 2015)
# ('Helldivers', 'Shooter', 2015)
# ('Project CARS', 'Racing', 2015)
# ('Project CARS', 'Racing', 2015)
# ('Project CARS', 'Racing', 2015)
# ('Broken Age: Act 2', 'Adventure', 2015)
# ('Bloodborne', 'Action', 2015)
# ('The Evil Within: The Assignment', 'Adventure', 2015)
# ('The Evil Within: The Assignment', 'Adventure', 2015)
# ('Halo 5: Guardians', 'Shooter', 2015)
# ('Broken Age: Act 2', 'Adventure', 2015)
# ('Crypt of the Necrodancer', 'Music, Adventure', 2015)
# ('Kerbal Space Program', 'Simulation', 2015)
# ('Rare Replay', 'Action, Compilation', 2015)
# ('Tales from the Borderlands -- Episode 3:  Catch a Ride', 'Adventure', 2015)
# ('Batman: Arkham Knight', 'Action', 2015)
# ('Batman: Arkham Knight', 'Action', 2015)
# ('Journey', 'Adventure', 2015)
# ('Fallout 4', 'RPG', 2015)
# ('Fallout 4', 'RPG', 2015)
# ('Fallout 4', 'RPG', 2015)
# ('Rise of the Tomb Raider', 'Action, Adventure', 2015)
# ('Rise of the Tomb Raider', 'Action, Adventure', 2015)
# ('Call of Duty: Black Ops III', 'Shooter', 2015)
# ('Call of Duty: Black Ops III', 'Shooter', 2015)
# ('Divinity: Original Sin -- Enhanced Edition', 'RPG', 2015)
# ('Divinity: Original Sin -- Enhanced Edition', 'RPG', 2015)
# ('Dirt Rally', 'Racing', 2015)
# ('Dirt Rally', 'Racing', 2015)
# ('Nuclear Throne', 'Action', 2015)
# ('The Room Three', 'Puzzle', 2015)
# ('Uncharted: The Nathan Drake Collection', 'Action', 2015)
# ('NBA 2K16', 'Sports', 2015)
# ('Assault Android Cactus', 'Shooter', 2015)
# ('Tales from the Borderlands -- Episode 5 The Vault of the Traveler', 'Adventure', 2015)
# ('Destiny: The Taken King', 'Shooter', 2015)
# ('Broforce', 'Action', 2015)
# ('Mushroom 11', 'Platformer', 2015)
# ('Darkest Dungeon', 'RPG', 2016)
# ('Darkest Dungeon', 'RPG', 2016)
# ('The Witness', 'Puzzle', 2016)
# ('The Witness', 'Puzzle', 2016)
# ('The Witness', 'Puzzle', 2016)
# ('Destiny: The Taken King', 'Shooter', 2015)
# ('Pro Evolution Soccer 2016', 'Sports', 2015)
# ('Mega Man Legacy Collection', 'Action', 2015)
# ('The Witcher 3: Wild Hunt -- Hearts of Stone', 'RPG', 2015)
# ('Fire Emblem Fates: Birthright', 'Strategy, RPG', 2016)
# ('Fire Emblem Fates: Conquest', 'Strategy, RPG', 2016)
# ('Forza Motorsport 6', 'Racing', 2015)
# ('Mega Man Legacy Collection', 'Action', 2015)
# ('Mega Man Legacy Collection', 'Action', 2015)
# ('Mega Man Legacy Collection', 'Action', 2015)
# ('Pony Island', 'Puzzle', 2016)
# ('Undertale', 'RPG', 2016)
# ('Undertale', 'RPG', 2016)
# ('Firewatch', 'Adventure', 2016)
# ('Firewatch', 'Adventure', 2016)
# ('Firewatch', 'Adventure', 2016)
# ('XCOM 2', 'Strategy', 2016)
# ('Super Mario Maker', 'Platformer', 2015)
# ('Metal Gear Solid V: The Phantom Pain', 'Action', 2015)
# ('Metal Gear Solid V: The Phantom Pain', 'Action', 2015)
# ('Metal Gear Solid V: The Phantom Pain', 'Action', 2015)
# ('Smite', 'Strategy', 2015)
# ('Forza Horizon 3', 'Racing', 2016)
# ('Pro Evolution Soccer 2017', 'Sports', 2016)
# ('Pro Evolution Soccer 2017', 'Sports', 2016)
# ('World of Warcraft: Legion', 'RPG', 2016)
# ('Stardew Valley', 'RPG, Simulation', 2016)
# ('Ratchet & Clank', 'Platformer', 2016)
# ('HTC Vive', 'Hardware', 2016)
# ('The Witcher 3: Wild Hunt -- Blood and Wine', 'RPG', 2016)
# ('Dark Souls III', 'Action, RPG', 2016)
# ('Dark Souls III', 'Action, RPG', 2016)
# ('Inside', 'Adventure', 2016)
# ("Uncharted 4: A Thief's End", 'Action, Adventure', 2016)
# ('Valkyria Chronicles Remastered', 'Action, RPG', 2016)
# ('MLB The Show 16', 'Sports', 2016)
# ('Oculus Rift', 'Hardware', 2016)
# ('Hearts of Iron IV', 'Strategy', 2016)
# ('Odin Sphere Leifthrasir', 'RPG', 2016)
# ('Odin Sphere Leifthrasir', 'RPG', 2016)
# ('Overwatch', 'Shooter', 2016)
# ('Overwatch', 'Shooter', 2016)
# ('Overwatch', 'Shooter', 2016)
# ('Deus Ex: Mankind Divided', 'Action, RPG', 2016)
# ('Deus Ex: Mankind Divided', 'Action, RPG', 2016)
# ('Deus Ex: Mankind Divided', 'Action, RPG', 2016)
# ('Kerbal Space Program', 'Simulation', 2016)
# ('Zero Time Dilemma', 'Adventure', 2016)
# ('Zero Time Dilemma', 'Adventure', 2016)
# ('Starbound', 'Action', 2016)
# ('LEGO Star Wars: The Force Awakens', 'Action, Adventure', 2016)
# ('Inside', 'Adventure', 2016)
# ('Inside', 'Adventure', 2016)

# %% [markdown]
# # Analysis of query:
#
# ## Notice that many of the games have scores >= 9, with the highest being a 9.7 (only 2 RPGs with this score as well as an IGN editors' coice award). However, quite a few also hover around a good, but less than outstanding, IGN score of 8 to 8.5.
#
# ## However, we would likely wonder how many games are in the dataset that recieved IGN editors' choice ratings, and what are the average IGN scores for these games? Are games with editors' choice awards rated quite a bit higher than the sample as a whole?

# %% [markdown]
# # How many games in the entire database received an IGN editors' choice award?

# %%
#import SQLAlchemy library 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, String, MetaData, Float, Integer, ForeignKey, Boolean

from sqlalchemy import event, select, func



#re-specify the password, host, and other info needed to access the database
db_string = "postgres://postgres:*******@localhost:5433/goods"
db_co = create_engine(db_string)

meta = MetaData(db_co)  

#specify the table so query can be done on it
ign_ratings = Table('ign_ratings', meta,
                      Column('ID', Integer, primary_key=True),
                      Column('score_phrase', String),
                      Column('title', String),
                      Column('url', String),
                      Column('platform', String),
                      Column('score', Float),
                      Column('genre', String),
                      Column('release_year', Integer),
                      Column('release_month', Integer),
                      Column('release_day', Integer),
                      Column('editors_choice_y', Integer),
                   )

with db_co.connect() as conn: 
    # do SELECT statement, and print out its output
    select_statement = select([func.count(ign_ratings.c.editors_choice_y)]).where(ign_ratings.c.editors_choice_y == 1)
    result_set = conn.execute(select_statement)
    for r in result_set:
        print(r)
# Out:
# (3517,)

# %% [markdown]
# ## Answer: 3,517 games in the dataset (roughly 19%) received an IGN editors' choice award. Therefore, IGN is somewhat selective in giving out these awards.
#
# # However, to what extent do the average IGN scores for these award recipients differ from the dataset as a whole? How do these average IGN scores differ when grouped by genre and year of release, respectively?

# %% [markdown]
# # What is the average IGN rating for the games that received an IGN editors' choice award?

# %%
#import SQLAlchemy library 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, String, MetaData, Float, Integer, ForeignKey, Boolean

from sqlalchemy import event, select, func


#specify the table so query can be done on it
ign_ratings = Table('ign_ratings', meta,
                      Column('ID', Integer, primary_key=True),
                      Column('score_phrase', String),
                      Column('title', String),
                      Column('url', String),
                      Column('platform', String),
                      Column('score', Float),
                      Column('genre', String),
                      Column('release_year', Integer),
                      Column('release_month', Integer),
                      Column('release_day', Integer),
                      Column('editors_choice_y', Integer),
                   )


#re-specify the password, host, and other info needed to access the database
db_string = "postgres://postgres:*******@localhost:5433/goods"
db_co = create_engine(db_string)

meta = MetaData(db_co) 




with db_co.connect() as conn: 
    # do SELECT statement, and print out its output
    select_statement = select([func.avg(ign_ratings.c.score)]).where(ign_ratings.c.editors_choice_y == 1)   
    result_set = conn.execute(select_statement)
    for r in result_set:
        print(r)
# Out:
# (8.86858117713961,)

# %% [markdown]
# # How do games with editors choice awards differ with the sample as a whole in terms of genre and release date?
#
# # Select all games' titles and release years for RPG games that received IGN editors' choice awards:
#
# ## I.e., PostgreSQL SELECT query syntax would be: <<< SELECT title, genre, and release_year FROM ign_ratings WHERE editors_choice_y =1 AND genre = 'RPG

# %%
#import SQLAlchemy library 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, String, MetaData, Float, Integer, ForeignKey, Boolean

from sqlalchemy import and_, select, event, func

#specify the table so query can be done on it
ign_ratings = Table('ign_ratings', meta,
                      Column('ID', Integer, primary_key=True),
                      Column('score_phrase', String),
                      Column('title', String),
                      Column('url', String),
                      Column('platform', String),
                      Column('score', Float),
                      Column('genre', String),
                      Column('release_year', Integer),
                      Column('release_month', Integer),
                      Column('release_day', Integer),
                      Column('editors_choice_y', Integer),
                   )

#re-specify the password, host, and other info needed to access the database
db_string = "postgres://postgres:*******@localhost:5433/goods"
db_co = create_engine(db_string)

meta = MetaData(db_co)  

with db_co.connect() as conn: 
    # do SELECT statement, and print out its output
    select_statement = select([ign_ratings.c.title,ign_ratings.c.score, ign_ratings.c.release_year]).where(and_(ign_ratings.c.editors_choice_y == 1,
                                                                                            ign_ratings.c.genre == 'RPG'))   
    result_set = conn.execute(select_statement)
    for r in result_set:
        print(r)
# Out:
# ('Guild Wars 2', 9.0, 2012)
# ('World of Warcraft: Mists of Pandaria', 8.7, 2012)
# ('Pokemon White Version 2', 9.6, 2012)
# ('Pokemon Black Version 2', 9.6, 2012)
# ('The World Ends with You: Solo Remix', 9.5, 2012)
# ('The World Ends with You: Solo Remix', 9.5, 2012)
# ('Ni no Kuni: Wrath of the White Witch', 9.4, 2013)
# ('Persona 4 Golden', 9.3, 2012)
# ('Mass Effect', 9.0, 2012)
# ('Final Fantasy VII', 9.5, 1997)
# ('Xenogears', 9.5, 1998)
# ('Might and Magic VI: The Mandate of Heaven', 9.0, 1998)
# ('Fallout 2', 8.9, 1998)
# ("Baldur's Gate", 9.4, 1999)
# ('EverQuest', 8.4, 1999)
# ('Pokemon Blue Version', 10.0, 1999)
# ('Pokemon Red Version', 10.0, 1999)
# ('Darkstone', 9.0, 1999)
# ('Final Fantasy VIII', 9.0, 1999)
# ('System Shock 2', 9.0, 1999)
# ('Final Fantasy Anthology', 9.0, 1999)
# ('Suikoden II', 9.0, 1999)
# ('Grandia', 9.0, 1999)
# ('Harvest Moon 64', 8.2, 1999)
# ('Planescape: Torment', 9.2, 1999)
# ('Dragon Warrior Monsters', 9.0, 2000)
# ('Front Mission 3', 8.8, 2000)
# ('Vagrant Story', 9.6, 2000)
# ('EverQuest: Ruins of Kunark', 8.5, 2000)
# ('Deus Ex', 9.4, 2000)
# ('Icewind Dale', 8.8, 2000)
# ('Legend of Mana', 8.3, 2000)
# ('Chrono Cross', 9.7, 2000)
# ('Wizards & Warriors [2000]', 8.4, 2000)
# ('Valkyrie Profile', 9.1, 2000)
# ('Pokemon Gold Version', 10.0, 2000)
# ("Baldur's Gate II: Shadows of Amn", 9.4, 2000)
# ('Pokemon Silver Version', 10.0, 2000)
# ('Skies of Arcadia', 9.2, 2000)
# ('Sea Dogs', 8.5, 2000)
# ('Final Fantasy IX', 9.2, 2000)
# ('Grandia II', 9.2, 2000)
# ('EverQuest: The Scars of Velious', 8.5, 2000)
# ('Persona 2: Eternal Punishment', 8.2, 2000)
# ('Final Fantasy', 8.6, 2001)
# ('Phantasy Star Online', 9.3, 2001)
# ('Paper Mario', 9.0, 2001)
# ('Icewind Dale: Heart of Winter', 8.6, 2001)
# ('Evil Islands: Curse of the Lost Soul', 8.7, 2001)
# ("Baldur's Gate II: Throne of Bhaal", 9.0, 2001)
# ('Dragon Warrior III', 10.0, 2001)
# ('Final Fantasy Chronicles', 9.4, 2001)
# ('Arcanum: Of Steamworks and Magick Obscura', 8.7, 2001)
# ('Pokemon Crystal Version', 9.0, 2001)
# ('Tales of Destiny II', 8.5, 2001)
# ('Phantasy Star Online Version 2', 8.5, 2001)
# ('Dark Age of Camelot', 9.0, 2001)
# ("Dragon Warrior Monsters 2: Tara's Adventure", 9.0, 2001)
# ("Dragon Warrior Monsters 2: Cobi's Journey", 9.0, 2001)
# ('Golden Sun', 9.7, 2001)
# ('Harvest Moon: Save the Homeland', 8.8, 2001)
# ('Wario Land 4', 9.0, 2001)
# ('Dragon Warrior VII', 8.7, 2001)
# ('EverQuest: Shadows of Luclin', 8.5, 2001)
# ('Final Fantasy X', 9.5, 2001)
# ('Freedom Force', 9.3, 2002)
# ('The Elder Scrolls III: Morrowind', 9.4, 2002)
# ('Arc the Lad Collection', 8.8, 2002)
# ('The Elder Scrolls III: Morrowind', 9.4, 2002)
# ('Neverwinter Nights', 9.0, 2002)
# ('Icewind Dale II', 9.0, 2002)
# ('Fallout 2', 8.9, 2002)
# ('Suikoden III', 9.4, 2002)
# ('Earth & Beyond', 8.8, 2002)
# ('Phantasy Star Online Episode I & II', 9.0, 2002)
# ('Divine Divinity', 8.5, 2002)
# ("Asheron's Call 2", 9.0, 2002)
# ('The Elder Scrolls III: Tribunal', 8.6, 2002)
# ('Crimson Sea', 8.1, 2003)
# ('Skies of Arcadia Legends', 8.5, 2003)
# ('Dark Age of Camelot: Shrouded Isles', 8.7, 2002)
# ('Anarchy Online: The Notum Wars', 8.8, 2002)
# ('Xenosaga Episode I: Der Wille zur Macht', 8.8, 2003)
# ('Pokemon Sapphire Version', 9.5, 2003)
# ('Pokemon Ruby Version', 9.5, 2003)
# ('A Tale in the Desert', 8.9, 2003)
# ('Final Fantasy Origins', 9.0, 2003)
# ("EverQuest for Pocket PC: Hero's Call", 8.5, 2003)
# ('The Elder Scrolls III: Bloodmoon', 8.9, 2003)
# ('Star Wars Knights of the Old Republic', 9.5, 2003)
# ('EverQuest: Lost Dungeons of Norrath', 8.5, 2003)
# ('Anarchy Online: Shadowlands', 8.8, 2003)
# ('Final Fantasy X-2', 9.5, 2003)
# ('Mario & Luigi: Superstar Saga', 9.0, 2003)
# ('Star Wars Knights of the Old Republic', 9.0, 2003)
# ('Neverwinter Nights: Hordes of the Underdark', 8.6, 2003)
# ('EverQuest: Gates of Discord', 9.0, 2004)
# ('Eye of Rana', 8.0, 2004)
# ('Final Fantasy XI', 8.8, 2004)
# ('City of Heroes', 8.4, 2004)
# ('Tales of Symphonia', 8.5, 2004)
# ('Pokemon LeafGreen Version', 9.0, 2004)
# ('Pokemon FireRed Version', 9.0, 2004)
# ('Neverwinter Nights', 8.6, 2004)
# ('Shin Megami Tensei: Nocturne', 8.6, 2004)
# ('Shadow Hearts: Covenant', 9.1, 2004)
# ('Paper Mario: The Thousand-Year Door', 9.1, 2004)
# ('Might and Magic', 9.1, 2004)
# ("Baldur's Gate", 8.4, 2004)
# ('EverQuest: Omens of War', 9.0, 2004)
# ('EverQuest II', 8.5, 2004)
# ('Star Wars Knights of the Old Republic II: The Sith Lords', 9.3, 2004)
# ('World of Warcraft', 9.1, 2004)
# ('Star Wars Knights of the Old Republic II: The Sith Lords', 8.7, 2005)
# ('Freedom Force vs. the 3rd Reich', 9.0, 2005)
# ('Jade Empire', 9.9, 2005)
# ('Guild Wars', 9.0, 2005)
# ('Harvest Moon: More Friends of Mineral Town', 8.5, 2005)
# ('Dungeon Siege II', 8.5, 2005)
# ('Doom RPG', 9.0, 2005)
# ('Dragon Quest VIII: Journey of the Cursed King', 9.0, 2005)
# ('Mario & Luigi: Partners in Time', 9.0, 2005)
# ('Final Fantasy IV Advance', 8.6, 2005)
# ('The Elder Scrolls IV: Oblivion', 9.3, 2006)
# ('The Elder Scrolls IV: Oblivion', 9.3, 2006)
# ('The Elder Scrolls IV: Oblivion', 8.4, 2006)
# ('Guild Wars Factions', 8.5, 2006)
# ('Valkyrie Profile: Lenneth', 8.5, 2006)
# ('Valkyrie Profile 2: Silmeria', 8.5, 2006)
# ('Dragon Quest Heroes: Rocket Slime', 8.5, 2006)
# ('Neverwinter Nights 2', 8.5, 2006)
# ("Final Fantasy XII (Collector's Edition)", 9.5, 2006)
# ('Final Fantasy XII', 9.5, 2006)
# ('Final Fantasy V Advance', 8.5, 2007)
# ('Rogue Galaxy', 8.7, 2007)
# ('World of Warcraft: The Burning Crusade', 8.8, 2007)
# ('Final Fantasy VI Advance', 9.0, 2007)
# ('Jade Empire (Special Edition)', 8.6, 2007)
# ('The Elder Scrolls IV: Oblivion', 9.2, 2007)
# ('The Elder Scrolls IV: The Shivering Isles', 8.5, 2007)
# ('Pokemon Pearl Version', 8.5, 2007)
# ('Pokemon Diamond Version', 8.5, 2007)
# ('Odin Sphere', 8.8, 2007)
# ('The Lord of the Rings Online: Shadows of Angmar', 8.6, 2007)
# ('Paper Mario', 9.0, 2007)
# ('Rune Factory: A Fantasy Harvest Moon', 8.4, 2007)
# ('Neverwinter Nights 2: Mask of the Betrayer', 8.5, 2007)
# ('The Witcher', 8.5, 2007)
# ("Mass Effect (Limited Collector's Edition)", 9.4, 2007)
# ('Mass Effect', 9.4, 2007)
# ('Orcs & Elves II', 8.5, 2007)
# ('Shin Megami Tensei: Persona 3 FES', 8.8, 2008)
# ('The World Ends with You', 9.0, 2008)
# ('Mass Effect', 9.2, 2008)
# ('Final Fantasy IV', 8.7, 2008)
# ('Super Mario RPG: Legend of the Seven Stars', 9.5, 2008)
# ('Shining Force II', 9.0, 2008)
# ("Warhammer Online: Age of Reckoning (Collector's Edition)", 9.0, 2008)
# ('Warhammer Online: Age of Reckoning', 9.0, 2008)
# ('Eternal Sonata', 8.7, 2008)
# ('Chrono Trigger', 8.8, 2008)
# ("World of Warcraft: Wrath of the Lich King (Collector's Edition)", 9.0, 2008)
# ('World of Warcraft: Wrath of the Lich King', 9.0, 2008)
# ('Shin Megami Tensei: Persona 4', 9.0, 2008)
# ('Phantasy Star IV', 9.0, 2009)
# ('Phantasy Star IV', 9.0, 2009)
# ('Dragon Quest V: Hand of the Heavenly Bride', 8.9, 2009)
# ('Valkyrie Profile: Covenant of the Plume', 8.5, 2009)
# ('Suikoden Tierkreis', 8.8, 2009)
# ('Pokemon Platinum Version', 8.8, 2009)
# ('Zenonia', 9.0, 2009)
# ('Shin Megami Tensei: Devil Survivor', 8.7, 2009)
# ('Wolfenstein RPG', 8.5, 2009)
# ('Phantasy Star', 8.5, 2009)
# ('Phantasy Star', 8.5, 2009)
# ('Dragon Quest Wars', 8.5, 2009)
# ('Final Fantasy', 8.5, 2009)
# ('Final Fantasy', 8.5, 2009)
# ('Aion', 8.5, 2009)
# ("Demon's Souls", 9.4, 2009)
# ('Half-Minute Hero', 8.8, 2009)
# ('Risen', 8.6, 2009)
# ("Dragon Age: Origins (Collector's Edition)", 8.7, 2009)
# ('Dragon Age: Origins', 8.7, 2009)
# ('Dragon Age: Origins', 9.0, 2009)
# ('Dragon Age: Origins', 8.7, 2009)
# ("Dragon Age: Origins (Collector's Edition)", 9.0, 2009)
# ("Dragon Age: Origins (Collector's Edition)", 8.7, 2009)
# ('The Lord of the Rings Online: Siege of Mirkwood', 9.0, 2010)
# ('Mass Effect 2', 9.6, 2010)
# ('Mass Effect 2', 9.6, 2010)
# ("Mass Effect 2 (Collector's Edition)", 9.6, 2010)
# ("Mass Effect 2 (Collector's Edition)", 9.6, 2010)
# ('Dragon Age: Origins -- Awakening', 8.5, 2010)
# ('Dragon Age: Origins -- Awakening', 8.5, 2010)
# ('Pokemon SoulSilver Version', 8.5, 2010)
# ('Pokemon HeartGold Version', 8.5, 2010)
# ('Star Ocean: The Last Hope International', 8.5, 2010)
# ('Dragon Age: Origins -- Return to Ostagar', 8.5, 2010)
# ('Dragon Age: Origins -- Return to Ostagar', 8.5, 2010)
# ('Final Fantasy XIII', 8.9, 2010)
# ('Final Fantasy XIII', 8.9, 2010)
# ('Lunar: Silver Star Harmony', 8.2, 2010)
# ('Dragon Age: Origins -- Awakening', 8.5, 2010)
# ('Final Fantasy II', 8.0, 2010)
# ('Shin Megami Tensei: Strange Journey', 8.5, 2010)
# ('3D Dot Game Heroes', 8.5, 2010)
# ('Chaos Rings', 9.0, 2010)
# ('Shin Megami Tensei: Persona 3 Portable', 8.5, 2010)
# ('Mass Effect 2: Overlord', 9.0, 2010)
# ('Mass Effect 2: Overlord', 9.0, 2010)
# ('Chaos Rings', 9.0, 2010)
# ('Phantasy Star II', 8.5, 2010)
# ('Fallout: New Vegas', 9.0, 2010)
# ('Fallout: New Vegas', 8.5, 2010)
# ('Fallout: New Vegas', 8.5, 2010)
# ('Mass Effect 2: Lair of the Shadow Broker', 9.5, 2010)
# ('Mass Effect 2: Lair of the Shadow Broker', 9.5, 2010)
# ('Fable III', 8.5, 2010)
# ('Lufia: Curse of the Sinistrals', 8.5, 2010)
# ('Mass Effect 2', 9.5, 2011)
# ('Dragon Age II', 8.5, 2011)
# ('Pokemon Black Version', 9.0, 2011)
# ('Pokemon White Version', 9.0, 2011)
# ('World of Warcraft: Cataclysm', 9.0, 2010)
# ('Radiant Historia', 8.5, 2011)
# ('Dragon Age II', 8.5, 2011)
# ('Dragon Age II', 8.5, 2011)
# ('Rift', 8.5, 2011)
# ('Final Fantasy IV: The Complete Collection', 9.0, 2011)
# ('The Witcher 2: Assassins of Kings', 9.0, 2011)
# ('Final Fantasy III (SNES)', 9.5, 2011)
# ('Dungeons of Dredmor', 8.5, 2011)
# ('Dragon Quest Monsters: Joker 2', 8.5, 2011)
# ('Dragon Age II -- Mark of the Assassin', 8.5, 2011)
# ('Dragon Age II -- Mark of the Assassin', 8.5, 2011)
# ('Dragon Age II -- Mark of the Assassin', 8.5, 2011)
# ('The Elder Scrolls V: Skyrim', 9.5, 2011)
# ('The Elder Scrolls V: Skyrim', 9.5, 2011)
# ('The Elder Scrolls V: Skyrim', 9.5, 2011)
# ('Kingdoms of Amalur: Reckoning', 9.0, 2012)
# ('Kingdoms of Amalur: Reckoning', 9.0, 2012)
# ('Kingdoms of Amalur: Reckoning', 9.0, 2012)
# ('Mass Effect 3', 9.5, 2012)
# ('Legend of Grimrock', 8.5, 2012)
# ('Mass Effect 3', 9.5, 2012)
# ('Mass Effect 3', 9.5, 2012)
# ('Xenoblade Chronicles', 9.0, 2012)
# ('The Last Story', 8.5, 2012)
# ('The Witcher 2: Assassins of Kings (Enhanced Edition)', 9.0, 2012)
# ('The Witcher 2: Assassins of Kings (Enhanced Edition)', 8.5, 2012)
# ('Star Wars: The Old Republic', 9.0, 2013)
# ('Rogue Legacy', 9.0, 2013)
# ('Rogue Legacy', 9.0, 2013)
# ('Rogue Legacy', 9.0, 2013)
# ('Rogue Legacy', 9.0, 2013)
# ('Dota 2', 9.4, 2013)
# ('Pokemon Y', 9.0, 2013)
# ('Pokemon X', 9.0, 2013)
# ('Final Fantasy X / X-2 HD Remaster', 9.3, 2014)
# ('Final Fantasy X / X-2 HD Remaster (Limited Edition)', 9.3, 2014)
# ('Final Fantasy X / X-2 HD Remaster', 9.3, 2014)
# ('South Park: The Stick of Truth', 9.0, 2014)
# ('South Park: The Stick of Truth', 9.0, 2014)
# ('South Park: The Stick of Truth', 9.0, 2014)
# ('Child of Light', 9.3, 2014)
# ('Child of Light', 9.3, 2014)
# ('Child of Light', 9.3, 2014)
# ('Child of Light', 9.3, 2014)
# ('Child of Light', 9.3, 2014)
# ('Child of Light', 9.3, 2014)
# ('Child of Light', 9.3, 2014)
# ('Divinity: Original Sin', 9.0, 2014)
# ('World of Warcraft: Warlords of Draenor', 9.0, 2014)
# ('The Binding of Isaac: Rebirth', 9.0, 2014)
# ('The Binding of Isaac: Rebirth', 9.0, 2014)
# ('The Witcher 3: Wild Hunt', 9.3, 2015)
# ('The Witcher 3: Wild Hunt', 9.3, 2015)
# ('The Witcher 3: Wild Hunt', 9.3, 2015)
# ('Final Fantasy X / X-2 HD Remaster', 9.3, 2015)
# ('Pillars of Eternity', 9.0, 2015)
# ('Fallout 4', 9.5, 2015)
# ('Fallout 4', 9.5, 2015)
# ('Fallout 4', 9.5, 2015)
# ('Divinity: Original Sin -- Enhanced Edition', 9.0, 2015)
# ('Divinity: Original Sin -- Enhanced Edition', 9.0, 2015)
# ('Darkest Dungeon', 9.1, 2016)
# ('Darkest Dungeon', 9.1, 2016)
# ('The Witcher 3: Wild Hunt -- Hearts of Stone', 9.0, 2015)
# ('Undertale', 10.0, 2016)
# ('Undertale', 10.0, 2016)
# ('World of Warcraft: Legion', 9.1, 2016)
# ('The Witcher 3: Wild Hunt -- Blood and Wine', 9.0, 2016)
# ('Odin Sphere Leifthrasir', 9.5, 2016)
# ('Odin Sphere Leifthrasir', 9.5, 2016)

# %% [markdown]
# ## Notice the average of all games that received an IGN editors' choice award--8.87--is nearly 2 full points higher than that of the sample average. Therefore, these awards are given out to games that, at least on average, are rated as being of a higher quality.

# %% [markdown]
# # What is the average IGN score for each release year in the database (i.e., 1996-2016)?
#
# ## Implement SELECT AVG(score)...WHERE query to compute this average:

# %%
#import SQLAlchemy library 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, String, MetaData, Float, Integer, ForeignKey, Boolean

from sqlalchemy import event, select, func

#specify the table so query can be done on it
ign_ratings = Table('ign_ratings', meta,
                      Column('ID', Integer, primary_key=True),
                      Column('score_phrase', String),
                      Column('title', String),
                      Column('url', String),
                      Column('platform', String),
                      Column('score', Float),
                      Column('genre', String),
                      Column('release_year', Integer),
                      Column('release_month', Integer),
                      Column('release_day', Integer),
                      Column('editors_choice_y', Integer),
                   )

#re-specify the password, host, and other info needed to access the database
db_string = "postgres://postgres:*******@localhost:5433/goods"
db_co = create_engine(db_string)

meta = MetaData(db_co)  

with db_co.connect() as conn: 
    # do SELECT statement, and print out its output
    select_statement = select([ign_ratings.c.release_year, func.avg(ign_ratings.c.score)]).where(ign_ratings.c.editors_choice_y == 1).group_by(ign_ratings.c.release_year).order_by(ign_ratings.c.release_year)   
    result_set = conn.execute(select_statement)
    for r in result_set:
        print(r)
# Out:
# (1996, 9.1125)
# (1997, 8.80625)
# (1998, 8.95116279069767)
# (1999, 9.003)
# (2000, 9.00059880239522)
# (2001, 8.98208092485549)
# (2002, 8.89122807017544)
# (2003, 8.87041198501873)
# (2004, 8.76062992125984)
# (2005, 8.7962962962963)
# (2006, 8.69640718562874)
# (2007, 8.71939655172415)
# (2008, 8.81428571428571)
# (2009, 8.83665480427046)
# (2010, 8.72925925925926)
# (2011, 8.75882352941177)
# (2012, 8.96619047619047)
# (2013, 9.15144927536231)
# (2014, 9.21443298969072)
# (2015, 9.09014084507042)
# (2016, 9.36888888888889)

# %% [markdown]
# # Analysis of query:
#
# ## As expected, the results of this query differ quite a bit from the sample average IGN scores for each year. While there appears to be a somewhat similar trend compared with the sample average IGN scores over time, average IGN scores over time for games with editors' choice awards were actually quite high in the late 1990s. This suggests that--while games as a whole during the late 1990s were of a lower quality than games from most years of the 2000s--the highest-quality games from the late 1990s were actually very top-notch.
#
# ## On the other hand, several of the highest average IGN ratings for games that received editors' choice awards ocurred during the period of 2012-2016, again suggesting that games during this period have been of a higher quality, whether judged as a whole or even among the highest-rated games.
